# %% [markdown]
# # SimpleTMG - All Datasets + Smartbuilding
#
# This Kaggle notebook runs the full SWT/FFT x original/dual attention experiment grid across the benchmark datasets plus the cleaned `smartbuilding/smart.csv` dataset.
#
# Variants:
# - `SWT_original`
# - `SWT_dual`
# - `FFT_original`
# - `FFT_dual`
#
# The notebook also syncs the current local repo changes into the Kaggle clone so the smartbuilding loader support and extended metrics are available during the run.

# %%
# !pip install PyWavelets gdown --quiet
import os
import json
import shutil
import subprocess
import pandas as pd
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %%
REPO_URL = "https://github.com/agamswami/SimpleTMG.git"
REPO_DIR = "/kaggle/working/SimpleTM"

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}

os.chdir(REPO_DIR)
print(f"Working directory: {os.getcwd()}")
# !sed -i 's/np\.Inf/np.inf/g' utils/tools.py
# Out:
# Cloning into '/kaggle/working/SimpleTM'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (197/197), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 197 (delta 88), reused 188 (delta 79), pack-reused 0 (from 0)
# Receiving objects: 100% (197/197), 23.01 MiB | 38.89 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# Working directory: /kaggle/working/SimpleTM

# %%
FILES_TO_SYNC = {"run.py": "import argparse\nimport torch\nfrom experiments.exp_long_term_forecasting import Exp_Long_Term_Forecast\nimport random\nimport numpy as np\nfrom model.SimpleTM import Model\nfrom model.SimpleTM_SWT import Model as Model_SWT\nfrom model.SimpleTM_FFT import Model as Model_FFT\n\nif __name__ == '__main__':\n\n    parser = argparse.ArgumentParser(description='iTransformer')\n\n    # basic config\n    parser.add_argument('--is_training', type=int, required=True, default=1, help='status')\n    parser.add_argument('--model_id', type=str, required=True, default='test', help='model id')\n\n    parser.add_argument('--model', type=str, required=True, default='SimpleTM',\n                        help='model name, options: [SimpleTM, SimpleTM_SWT, SimpleTM_FFT]')\n\n    # data loader\n    parser.add_argument('--data', type=str, required=True, default='custom', help='dataset type')\n    parser.add_argument('--root_path', type=str, default='./data/electricity/', help='root path of the data file')\n    parser.add_argument('--data_path', type=str, default='electricity.csv', help='data csv file')\n    parser.add_argument('--features', type=str, default='M',\n                        help='forecasting task, options:[M, S, MS]; M:multivariate predict multivariate, S:univariate predict univariate, MS:multivariate predict univariate')\n    parser.add_argument('--target', type=str, default='OT', help='target feature in S or MS task')\n    parser.add_argument('--freq', type=str, default='h',\n                        help='freq for time features encoding, options:[s:secondly, t:minutely, h:hourly, d:daily, b:business days, w:weekly, m:monthly], you can also use more detailed freq like 15min or 3h')\n    parser.add_argument('--checkpoints', type=str, default='./checkpoints/', help='location of model checkpoints')\n\n    # forecasting task\n    parser.add_argument('--seq_len', type=int, default=96, help='input sequence length')\n    parser.add_argument('--label_len', type=int, default=0, help='start token length')\n    parser.add_argument('--pred_len', type=int, default=96, help='prediction sequence length')\n\n    # model define\n    parser.add_argument('--enc_in', type=int, default=7, help='encoder input size')\n    parser.add_argument('--dec_in', type=int, default=7, help='decoder input size')\n    parser.add_argument('--c_out', type=int, default=7, help='output size') \n    parser.add_argument('--n_heads', type=int, default=8, help='num of heads')\n    parser.add_argument('--d_layers', type=int, default=1, help='num of decoder layers')\n    parser.add_argument('--moving_avg', type=int, default=25, help='window size of moving average')\n    parser.add_argument('--factor', type=int, default=1, help='attn factor')\n    parser.add_argument('--distil', action='store_false',\n                        help='whether to use distilling in encoder, using this argument means not using distilling',\n                        default=True)\n    parser.add_argument('--dropout', type=float, default=0.1, help='dropout')\n    parser.add_argument('--geomattn_dropout', type=float, default=0.5, help='dropout rate of the projection layer in the geometric attention')\n    parser.add_argument('--embed', type=str, default='timeF',\n                        help='time features encoding, options:[timeF, fixed, learned]')\n    parser.add_argument('--activation', type=str, default='gelu', help='activation')\n    parser.add_argument('--do_predict', action='store_true', help='whether to predict unseen future data')\n\n    # optimization\n    parser.add_argument('--num_workers', type=int, default=10, help='data loader num workers')\n    parser.add_argument('--itr', type=int, default=1, help='experiments times')\n    parser.add_argument('--train_epochs', type=int, default=10, help='train epochs')\n    parser.add_argument('--batch_size', type=int, default=32, help='batch size of train input data')\n    parser.add_argument('--patience', type=int, default=3, help='early stopping patience')\n    parser.add_argument('--learning_rate', type=float, default=0.0001, help='optimizer learning rate')\n    parser.add_argument('--des', type=str, default='test', help='exp description')\n    parser.add_argument('--loss', type=str, default='MSE', help='loss function')\n    parser.add_argument('--lradj', type=str, default='type1', help='adjust learning rate')\n    parser.add_argument('--pct_start', type=float, default=0.2, help='Warmup ratio for the learning rate scheduler')\n    parser.add_argument('--use_amp', action='store_true', help='use automatic mixed precision training', default=False)\n\n    # GPU\n    parser.add_argument('--use_gpu', type=bool, default=True, help='use gpu')\n    parser.add_argument('--gpu', type=int, default=0, help='gpu')\n    parser.add_argument('--use_multi_gpu', action='store_true', help='use multiple gpus', default=False)\n    parser.add_argument('--devices', type=str, default='0,1,2,3', help='device ids of multile gpus')\n\n    parser.add_argument('--exp_name', type=str, required=False, default='MTSF',\n                        help='experiemnt name, options:[MTSF, partial_train]')\n    parser.add_argument('--channel_independence', type=bool, default=False, help='whether to use channel_independence mechanism')\n    parser.add_argument('--inverse', action='store_true', help='inverse output data', default=False)\n    parser.add_argument('--class_strategy', type=str, default='projection', help='projection/average/cls_token')\n    parser.add_argument('--target_root_path', type=str, default='./data/electricity/', help='root path of the data file')\n    parser.add_argument('--target_data_path', type=str, default='electricity.csv', help='data file')\n    parser.add_argument('--efficient_training', type=bool, default=False, help='whether to use efficient_training (exp_name should be partial train)') # See Figure 8 of our paper for the detail\n    parser.add_argument('--use_norm', type=int, default=True, help='use norm and denorm')\n    parser.add_argument('--partial_start_index', type=int, default=0, help='the start index of variates for partial training, '\n                                                                           'you can select [partial_start_index, min(enc_in + partial_start_index, N)]')\n\n    # SimpleTM Arguments\n    parser.add_argument('--requires_grad', type=bool, default=True, help='Set to True to enable learnable wavelets')\n    parser.add_argument('--wv', type=str, default='db1', help='Wavelet filter type. Supports all wavelets available in PyTorch Wavelets')\n    parser.add_argument('--m', type=int, default=3, help='Number of levels for the stationary wavelet transform')\n    parser.add_argument('--kernel_size', default=None, help='Specify the length of randomly initialized wavelets (if not None)')\n    parser.add_argument('--alpha', type=float, default=1, help='Weight of the inner product score in geometric attention')\n    parser.add_argument('--l1_weight', type=float, default=5e-5, help='Weight of L1 loss')\n    parser.add_argument('--d_model', type=int, default=32, help='Dimensionality of pseudo tokens')\n    parser.add_argument('--d_ff', type=int, default=32, help='Dimensionality of the feedforward network')\n    parser.add_argument('--e_layers', type=int, default=1, help='Number of SimpleTM layers')\n    parser.add_argument('--compile', type=bool, default=False, help='Set to True to enable compilation, which can accelerate speed but may slightly impact performance')\n    parser.add_argument('--output_attention', action='store_true', help='Set to False to output attn, which can be used to compute training loss')\n    parser.add_argument('--attention_mode', type=str, default='original',\n                        help='attention variant, options: [original, dual]. dual adds a parallel temporal attention branch.')\n\n    parser.add_argument('--fix_seed', type=int, default=2025, help='gpu')\n    \n    args = parser.parse_args()\n    args.use_gpu = True if torch.cuda.is_available() and args.use_gpu else False\n\n    fix_seed = args.fix_seed\n    random.seed(fix_seed)\n    torch.manual_seed(fix_seed)\n    np.random.seed(fix_seed)\n\n    if args.use_gpu and args.use_multi_gpu:\n        args.devices = args.devices.replace(' ', '')\n        device_ids = args.devices.split(',')\n        args.device_ids = [int(id_) for id_ in device_ids]\n        args.gpu = args.device_ids[0]\n\n    print('Args in experiment:')\n    print(args)\n\n    Exp = Exp_Long_Term_Forecast\n\n    if args.is_training:\n        for ii in range(args.itr):\n            # setting record of experiments\n            setting = '{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}'.format(\n                args.model_id, \n                args.data,\n                args.seq_len,\n                args.pred_len,\n                args.d_model,\n                args.d_ff,\n                args.e_layers,   \n                args.wv,\n                args.kernel_size,\n                args.m,\n                args.alpha,\n                args.l1_weight, \n                args.learning_rate,\n                args.lradj,\n                args.batch_size,\n                args.fix_seed,\n                args.use_norm,\n                ii)\n\n            exp = Exp(args)  # set experiments\n            print('>>>>>>>start training : {}>>>>>>>>>>>>>>>>>>>>>>>>>>'.format(setting))\n            exp.train(setting)\n\n            print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))\n            exp.test(setting)\n\n            if args.do_predict:\n                print('>>>>>>>predicting : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))\n                exp.predict(setting, True)\n\n            torch.cuda.empty_cache()\n    else:\n      \n        ii = 0\n        setting = '{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}_{}'.format(\n            args.data,\n            args.seq_len,\n            args.pred_len,\n            args.d_model,\n            args.d_ff,\n            args.e_layers,\n            args.wv,\n            args.kernel_size,\n            args.m,\n            args.alpha,\n            args.l1_weight, \n            args.learning_rate,\n            args.lradj,\n            args.batch_size,\n            args.fix_seed,\n            args.use_norm,\n            ii)\n\n        exp = Exp(args)  # set experiments\n        print('>>>>>>>testing : {}<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<'.format(setting))\n        exp.test(setting, test=1)\n        torch.cuda.empty_cache()\n", "model/SimpleTM.py": "import torch\nimport torch.nn as nn\nimport torch.nn.functional as F\nfrom layers.Transformer_Encoder import Encoder, EncoderLayer\nfrom layers.SWTAttention_Family import GeomAttentionLayer, GeomAttention\nfrom layers.ParallelAttention_Family import ParallelSWTGeomAttentionLayer\nfrom layers.Embed import DataEmbedding_inverted\n\n\nclass Model(nn.Module):\n    def __init__(self, configs):\n        super(Model, self).__init__()\n        self.seq_len = configs.seq_len\n        self.pred_len = configs.pred_len\n        self.output_attention = configs.output_attention\n        self.use_norm = configs.use_norm\n        self.geomattn_dropout = configs.geomattn_dropout\n        self.alpha = configs.alpha\n        self.kernel_size = configs.kernel_size\n        self.attention_mode = getattr(configs, 'attention_mode', 'original')\n\n        attention_layer_cls = GeomAttentionLayer\n        if self.attention_mode == 'dual':\n            attention_layer_cls = ParallelSWTGeomAttentionLayer\n\n        enc_embedding = DataEmbedding_inverted(configs.seq_len, configs.d_model, \n                                               configs.embed, configs.freq, configs.dropout)\n        self.enc_embedding = enc_embedding\n\n        encoder = Encoder(\n            [  \n                EncoderLayer(\n                    attention_layer_cls(\n                        GeomAttention(\n                            False, configs.factor, attention_dropout=configs.dropout, \n                            output_attention=configs.output_attention, alpha=self.alpha\n                        ),\n                        configs.d_model, \n                        requires_grad=configs.requires_grad, \n                        wv=configs.wv, \n                        m=configs.m, \n                        d_channel=configs.dec_in, \n                        kernel_size=self.kernel_size, \n                        geomattn_dropout=self.geomattn_dropout\n                    ),\n                    configs.d_model,\n                    configs.d_ff,\n                    dropout=configs.dropout,\n                    activation=configs.activation,\n                ) for l in range(configs.e_layers) \n            ],\n            norm_layer=torch.nn.LayerNorm(configs.d_model)\n        )\n        self.encoder = encoder\n\n        projector = nn.Linear(configs.d_model, self.pred_len, bias=True)\n        self.projector = projector\n\n\n    def forecast(self, x_enc, x_mark_enc, x_dec, x_mark_dec):\n        if self.use_norm:\n            means = x_enc.mean(1, keepdim=True).detach()\n            x_enc = x_enc - means\n            stdev = torch.sqrt(torch.var(x_enc, dim=1, keepdim=True, unbiased=False) + 1e-5)\n            # x_enc /= stdev\n            x_enc = x_enc / stdev\n\n        _, _, N = x_enc.shape\n\n        enc_embedding = self.enc_embedding\n        encoder = self.encoder\n        projector = self.projector\n        # Linear Projection             B L N -> B L' (pseudo temporal tokens) N \n        enc_out = enc_embedding(x_enc, x_mark_enc) \n\n        # SimpleTM Layer                B L' N -> B L' N \n        enc_out, attns = encoder(enc_out, attn_mask=None)\n\n        # Output Projection             B L' N -> B H (Horizon) N\n        dec_out = projector(enc_out).permute(0, 2, 1)[:, :, :N] \n\n        if self.use_norm:\n            dec_out = dec_out * (stdev[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n            dec_out = dec_out + (means[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n\n        return dec_out, attns\n\n\n    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):\n        dec_out, attns = self.forecast(x_enc, None, None, None)\n        return dec_out, attns \n", "model/SimpleTM_SWT.py": "\"\"\"\nSimpleTM_SWT: SWT-Only Tokenization Model\n\nThis is the original SimpleTM model documented as the SWT-only tokenization baseline.\nIt uses Stationary Wavelet Transform (SWT) for tokenization and Geometric Attention\n(wedge product + dot product) for inter-variate attention.\n\nPipeline:\n    1. Instance Normalization (RevIN)\n    2. Inverted Embedding: (B, L, N) \u2192 (B, N, d_model) \u2014 channel-independent temporal tokens\n    3. SWT Tokenization: Decomposes each token via SWT into multi-scale coefficients\n    4. Geometric Attention: Wedge product scoring across variates at each scale\n    5. SWT Reconstruction: Inverse SWT to reconstruct from multi-scale representation\n    6. Output Projection: (B, N, d_model) \u2192 (B, H, N) \u2014 forecast horizon\n    7. De-normalization\n\"\"\"\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\nfrom layers.Transformer_Encoder import Encoder, EncoderLayer\nfrom layers.SWTAttention_Family import GeomAttentionLayer, GeomAttention\nfrom layers.ParallelAttention_Family import ParallelSWTGeomAttentionLayer\nfrom layers.Embed import DataEmbedding_inverted\n\n\nclass Model(nn.Module):\n    \"\"\"\n    SimpleTM with SWT-Only Tokenization (Original Baseline).\n    \n    This is functionally identical to the original SimpleTM model.\n    Kept as a separate file for clean ablation study comparison.\n    \n    Args:\n        configs: Configuration namespace containing:\n            - seq_len (int): Input sequence length\n            - pred_len (int): Prediction horizon length\n            - output_attention (bool): Whether to output attention weights\n            - use_norm (bool): Whether to apply instance normalization\n            - geomattn_dropout (float): Dropout rate in attention projections\n            - alpha (float): Weight balancing dot product vs wedge product in GeomAttention\n            - kernel_size (int|None): Wavelet kernel size (None = use wavelet default)\n            - d_model (int): Pseudo token dimensionality\n            - d_ff (int): Feed-forward network dimensionality\n            - e_layers (int): Number of encoder layers\n            - enc_in (int): Number of input variates\n            - dec_in (int): Number of channels for wavelet embedding\n            - embed (str): Time embedding type\n            - freq (str): Data frequency\n            - dropout (float): General dropout\n            - requires_grad (bool): Whether wavelet filters are learnable\n            - wv (str): Wavelet family (e.g., 'db1', 'db2')\n            - m (int): Number of SWT decomposition levels\n            - factor (int): Attention factor\n            - activation (str): Activation function ('relu' or 'gelu')\n    \"\"\"\n    def __init__(self, configs):\n        super(Model, self).__init__()\n        self.seq_len = configs.seq_len\n        self.pred_len = configs.pred_len\n        self.output_attention = configs.output_attention\n        self.use_norm = configs.use_norm\n        self.geomattn_dropout = configs.geomattn_dropout\n        self.alpha = configs.alpha\n        self.kernel_size = configs.kernel_size\n        self.attention_mode = getattr(configs, 'attention_mode', 'original')\n\n        attention_layer_cls = GeomAttentionLayer\n        if self.attention_mode == 'dual':\n            attention_layer_cls = ParallelSWTGeomAttentionLayer\n\n        # Step 1: Inverted Embedding \u2014 project temporal dim to d_model\n        enc_embedding = DataEmbedding_inverted(configs.seq_len, configs.d_model, \n                                               configs.embed, configs.freq, configs.dropout)\n        self.enc_embedding = enc_embedding\n\n        # Step 2: Encoder with SWT tokenization + Geometric Attention\n        encoder = Encoder(\n            [  \n                EncoderLayer(\n                    attention_layer_cls(\n                        GeomAttention(\n                            False, configs.factor, attention_dropout=configs.dropout, \n                            output_attention=configs.output_attention, alpha=self.alpha\n                        ),\n                        configs.d_model, \n                        requires_grad=configs.requires_grad, \n                        wv=configs.wv, \n                        m=configs.m, \n                        d_channel=configs.dec_in, \n                        kernel_size=self.kernel_size, \n                        geomattn_dropout=self.geomattn_dropout\n                    ),\n                    configs.d_model,\n                    configs.d_ff,\n                    dropout=configs.dropout,\n                    activation=configs.activation,\n                ) for l in range(configs.e_layers) \n            ],\n            norm_layer=torch.nn.LayerNorm(configs.d_model)\n        )\n        self.encoder = encoder\n\n        # Step 3: Output Projection \u2014 project d_model to prediction horizon\n        projector = nn.Linear(configs.d_model, self.pred_len, bias=True)\n        self.projector = projector\n\n\n    def forecast(self, x_enc, x_mark_enc, x_dec, x_mark_dec):\n        \"\"\"\n        Forward pass for forecasting.\n        \n        Args:\n            x_enc: (B, L, N) input time series\n            x_mark_enc: Time features (unused, passed as None)\n            x_dec: Decoder input (unused)\n            x_mark_dec: Decoder time features (unused)\n            \n        Returns:\n            dec_out: (B, H, N) forecasted values\n            attns: List of attention weights from each encoder layer\n        \"\"\"\n        # Instance Normalization (RevIN-style)\n        if self.use_norm:\n            means = x_enc.mean(1, keepdim=True).detach()\n            x_enc = x_enc - means\n            stdev = torch.sqrt(torch.var(x_enc, dim=1, keepdim=True, unbiased=False) + 1e-5)\n            x_enc = x_enc / stdev\n\n        _, _, N = x_enc.shape\n\n        enc_embedding = self.enc_embedding\n        encoder = self.encoder\n        projector = self.projector\n\n        # Inverted Embedding:       B L N -> B N d_model (pseudo temporal tokens)\n        enc_out = enc_embedding(x_enc, x_mark_enc) \n\n        # Encoder (SWT + GeomAttn): B N d_model -> B N d_model\n        enc_out, attns = encoder(enc_out, attn_mask=None)\n\n        # Output Projection:        B N d_model -> B H N\n        dec_out = projector(enc_out).permute(0, 2, 1)[:, :, :N] \n\n        # De-normalization\n        if self.use_norm:\n            dec_out = dec_out * (stdev[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n            dec_out = dec_out + (means[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n\n        return dec_out, attns\n\n\n    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):\n        \"\"\"\n        Main forward method.\n        \n        Args:\n            x_enc: (B, L, N) input time series\n            x_mark_enc: Time features\n            x_dec: Decoder input\n            x_mark_dec: Decoder time features\n            mask: Optional mask\n            \n        Returns:\n            dec_out: (B, H, N) forecasted values\n            attns: Attention weights\n        \"\"\"\n        dec_out, attns = self.forecast(x_enc, None, None, None)\n        return dec_out, attns \n", "model/SimpleTM_FFT.py": "\"\"\"\nSimpleTM_FFT: FFT-Only Tokenization Model\n\nThis variant replaces the Stationary Wavelet Transform (SWT) tokenization \nwith Fast Fourier Transform (FFT) spectral decomposition, while keeping \nthe Geometric Attention (wedge product + dot product) mechanism unchanged.\n\nInstead of decomposing signals into wavelet approximation and detail \ncoefficients, FFT tokenization splits the frequency spectrum into m+1 \nbands, creating spectral tokens at different frequency scales.\n\nPipeline:\n    1. Instance Normalization (RevIN)\n    2. Inverted Embedding: (B, L, N) \u2192 (B, N, d_model) \u2014 channel-independent temporal tokens\n    3. FFT Tokenization: Decomposes each token via FFT into frequency band signals\n    4. Geometric Attention: Wedge product scoring across variates at each frequency band\n    5. FFT Reconstruction: Sum frequency bands to reconstruct signal\n    6. Output Projection: (B, N, d_model) \u2192 (B, H, N) \u2014 forecast horizon\n    7. De-normalization\n\"\"\"\nimport torch\nimport torch.nn as nn\nimport torch.nn.functional as F\nfrom layers.Transformer_Encoder import Encoder, EncoderLayer\nfrom layers.FFTAttention_Family import FFTGeomAttentionLayer\nfrom layers.ParallelAttention_Family import ParallelFFTGeomAttentionLayer\nfrom layers.SWTAttention_Family import GeomAttention\nfrom layers.Embed import DataEmbedding_inverted\n\n\nclass Model(nn.Module):\n    \"\"\"\n    SimpleTM with FFT-Only Tokenization.\n    \n    Replaces SWT wavelet decomposition with FFT spectral band decomposition.\n    Geometric attention (wedge product scoring) remains unchanged.\n    \n    Args:\n        configs: Configuration namespace containing:\n            - seq_len (int): Input sequence length\n            - pred_len (int): Prediction horizon length\n            - output_attention (bool): Whether to output attention weights\n            - use_norm (bool): Whether to apply instance normalization\n            - geomattn_dropout (float): Dropout rate in attention projections\n            - alpha (float): Weight balancing dot product vs wedge product\n            - d_model (int): Pseudo token dimensionality\n            - d_ff (int): Feed-forward network dimensionality\n            - e_layers (int): Number of encoder layers\n            - enc_in (int): Number of input variates\n            - dec_in (int): Number of channels for FFT embedding\n            - embed (str): Time embedding type\n            - freq (str): Data frequency\n            - dropout (float): General dropout\n            - m (int): Number of FFT frequency bands (m+1 total bands)\n            - factor (int): Attention factor\n            - activation (str): Activation function ('relu' or 'gelu')\n    \"\"\"\n    def __init__(self, configs):\n        super(Model, self).__init__()\n        self.seq_len = configs.seq_len\n        self.pred_len = configs.pred_len\n        self.output_attention = configs.output_attention\n        self.use_norm = configs.use_norm\n        self.geomattn_dropout = configs.geomattn_dropout\n        self.alpha = configs.alpha\n        self.attention_mode = getattr(configs, 'attention_mode', 'original')\n\n        attention_layer_cls = FFTGeomAttentionLayer\n        if self.attention_mode == 'dual':\n            attention_layer_cls = ParallelFFTGeomAttentionLayer\n\n        # Step 1: Inverted Embedding \u2014 project temporal dim to d_model\n        enc_embedding = DataEmbedding_inverted(configs.seq_len, configs.d_model, \n                                               configs.embed, configs.freq, configs.dropout)\n        self.enc_embedding = enc_embedding\n\n        # Step 2: Encoder with FFT tokenization + Geometric Attention\n        encoder = Encoder(\n            [  \n                EncoderLayer(\n                    attention_layer_cls(\n                        GeomAttention(\n                            False, configs.factor, attention_dropout=configs.dropout, \n                            output_attention=configs.output_attention, alpha=self.alpha\n                        ),\n                        configs.d_model, \n                        m=configs.m, \n                        d_channel=configs.dec_in, \n                        geomattn_dropout=self.geomattn_dropout\n                    ),\n                    configs.d_model,\n                    configs.d_ff,\n                    dropout=configs.dropout,\n                    activation=configs.activation,\n                ) for l in range(configs.e_layers) \n            ],\n            norm_layer=torch.nn.LayerNorm(configs.d_model)\n        )\n        self.encoder = encoder\n\n        # Step 3: Output Projection \u2014 project d_model to prediction horizon\n        projector = nn.Linear(configs.d_model, self.pred_len, bias=True)\n        self.projector = projector\n\n\n    def forecast(self, x_enc, x_mark_enc, x_dec, x_mark_dec):\n        \"\"\"\n        Forward pass for forecasting.\n        \n        Args:\n            x_enc: (B, L, N) input time series\n            x_mark_enc: Time features (unused, passed as None)\n            x_dec: Decoder input (unused)\n            x_mark_dec: Decoder time features (unused)\n            \n        Returns:\n            dec_out: (B, H, N) forecasted values\n            attns: List of attention weights from each encoder layer\n        \"\"\"\n        # Instance Normalization (RevIN-style)\n        if self.use_norm:\n            means = x_enc.mean(1, keepdim=True).detach()\n            x_enc = x_enc - means\n            stdev = torch.sqrt(torch.var(x_enc, dim=1, keepdim=True, unbiased=False) + 1e-5)\n            x_enc = x_enc / stdev\n\n        _, _, N = x_enc.shape\n\n        enc_embedding = self.enc_embedding\n        encoder = self.encoder\n        projector = self.projector\n\n        # Inverted Embedding:       B L N -> B N d_model (pseudo temporal tokens)\n        enc_out = enc_embedding(x_enc, x_mark_enc) \n\n        # Encoder (FFT + GeomAttn): B N d_model -> B N d_model\n        enc_out, attns = encoder(enc_out, attn_mask=None)\n\n        # Output Projection:        B N d_model -> B H N\n        dec_out = projector(enc_out).permute(0, 2, 1)[:, :, :N] \n\n        # De-normalization\n        if self.use_norm:\n            dec_out = dec_out * (stdev[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n            dec_out = dec_out + (means[:, 0, :].unsqueeze(1).repeat(1, self.pred_len, 1))\n\n        return dec_out, attns\n\n\n    def forward(self, x_enc, x_mark_enc, x_dec, x_mark_dec, mask=None):\n        \"\"\"\n        Main forward method.\n        \n        Args:\n            x_enc: (B, L, N) input time series\n            x_mark_enc: Time features\n            x_dec: Decoder input\n            x_mark_dec: Decoder time features\n            mask: Optional mask\n            \n        Returns:\n            dec_out: (B, H, N) forecasted values\n            attns: Attention weights\n        \"\"\"\n        dec_out, attns = self.forecast(x_enc, None, None, None)\n        return dec_out, attns \n", "layers/ParallelAttention_Family.py": "import torch\nimport torch.nn as nn\nfrom math import sqrt\n\nfrom layers.SWTAttention_Family import GeomAttentionLayer\nfrom layers.FFTAttention_Family import FFTGeomAttentionLayer\n\n\nclass TemporalAxisAttention(nn.Module):\n    \"\"\"Self-attention over the latent time axis after inverted embedding.\"\"\"\n\n    def __init__(self, d_channel, attention_dropout=0.1):\n        super().__init__()\n        self.scale = 1.0 / sqrt(d_channel)\n        self.query_projection = nn.Linear(d_channel, d_channel)\n        self.key_projection = nn.Linear(d_channel, d_channel)\n        self.value_projection = nn.Linear(d_channel, d_channel)\n        self.out_projection = nn.Linear(d_channel, d_channel)\n        self.dropout = nn.Dropout(attention_dropout)\n\n    def forward(self, queries, keys, values):\n        # Convert (B, N, D) into time-major tokens (B, D, N).\n        queries = queries.transpose(1, 2)\n        keys = keys.transpose(1, 2)\n        values = values.transpose(1, 2)\n\n        q = self.query_projection(queries)\n        k = self.key_projection(keys)\n        v = self.value_projection(values)\n\n        scores = torch.matmul(q, k.transpose(-2, -1)) * self.scale\n        attn = self.dropout(torch.softmax(scores, dim=-1))\n        out = torch.matmul(attn, v)\n        out = self.out_projection(out)\n\n        return out.transpose(1, 2), scores.abs().mean()\n\n\nclass _ParallelAttentionBase(nn.Module):\n    def __init__(self, original_attention_layer, d_model, d_channel, branch_dropout=0.1):\n        super().__init__()\n        self.original_attention_layer = original_attention_layer\n        self.temporal_attention = TemporalAxisAttention(\n            d_channel=d_channel, attention_dropout=branch_dropout\n        )\n        self.gate = nn.Sequential(\n            nn.Linear(2 * d_model, d_model),\n            nn.GELU(),\n            nn.Linear(d_model, 1),\n        )\n\n    def forward(self, queries, keys, values, attn_mask=None, tau=None, delta=None):\n        channel_out, channel_attn = self.original_attention_layer(\n            queries, keys, values, attn_mask=attn_mask, tau=tau, delta=delta\n        )\n        temporal_out, temporal_attn = self.temporal_attention(queries, keys, values)\n\n        pooled = torch.cat(\n            [channel_out.mean(dim=1), temporal_out.mean(dim=1)], dim=-1\n        )\n        gate = torch.sigmoid(self.gate(pooled)).unsqueeze(-1)\n        out = gate * channel_out + (1.0 - gate) * temporal_out\n\n        return out, 0.5 * (channel_attn + temporal_attn)\n\n\nclass ParallelSWTGeomAttentionLayer(_ParallelAttentionBase):\n    \"\"\"Original SWT geometric attention plus a parallel temporal branch.\"\"\"\n\n    def __init__(\n        self,\n        attention,\n        d_model,\n        requires_grad=True,\n        wv=\"db2\",\n        m=2,\n        kernel_size=None,\n        d_channel=None,\n        geomattn_dropout=0.5,\n    ):\n        original_attention_layer = GeomAttentionLayer(\n            attention,\n            d_model,\n            requires_grad=requires_grad,\n            wv=wv,\n            m=m,\n            kernel_size=kernel_size,\n            d_channel=d_channel,\n            geomattn_dropout=geomattn_dropout,\n        )\n        super().__init__(\n            original_attention_layer=original_attention_layer,\n            d_model=d_model,\n            d_channel=d_channel,\n            branch_dropout=geomattn_dropout,\n        )\n\n\nclass ParallelFFTGeomAttentionLayer(_ParallelAttentionBase):\n    \"\"\"Original FFT geometric attention plus a parallel temporal branch.\"\"\"\n\n    def __init__(self, attention, d_model, m=2, d_channel=None, geomattn_dropout=0.5):\n        original_attention_layer = FFTGeomAttentionLayer(\n            attention,\n            d_model,\n            m=m,\n            d_channel=d_channel,\n            geomattn_dropout=geomattn_dropout,\n        )\n        super().__init__(\n            original_attention_layer=original_attention_layer,\n            d_model=d_model,\n            d_channel=d_channel,\n            branch_dropout=geomattn_dropout,\n        )\n", "data_provider/data_loader.py": "import os\nimport numpy as np\nimport pandas as pd\nimport torch\nfrom torch.utils.data import Dataset, DataLoader\nfrom sklearn.preprocessing import StandardScaler\nfrom utils.timefeatures import time_features\nimport warnings\n\nwarnings.filterwarnings('ignore')\n\n\ndef _resolve_datetime_column(df_raw):\n    for name in df_raw.columns:\n        if name.lower() in {'date', 'datetime', 'timestamp', 'time'}:\n            return name\n    raise ValueError(\n        \"No datetime column found. Expected one of: date, datetime, timestamp, time.\"\n    )\n\n\ndef _resolve_target_column(df_raw, target, features):\n    if target in df_raw.columns:\n        return target\n\n    lower_to_actual = {col.lower(): col for col in df_raw.columns}\n    if target.lower() in lower_to_actual:\n        return lower_to_actual[target.lower()]\n\n    if features == 'M':\n        return None\n\n    raise ValueError(\n        f\"Target column '{target}' not found in dataset columns: {list(df_raw.columns)}\"\n    )\n\n\ndef _prepare_custom_dataframe(df_raw, target, features):\n    date_col = _resolve_datetime_column(df_raw)\n    target_col = _resolve_target_column(df_raw, target, features)\n\n    feature_cols = [col for col in df_raw.columns if col != date_col]\n    if target_col is not None and target_col in feature_cols:\n        feature_cols.remove(target_col)\n\n    ordered_cols = [date_col] + feature_cols\n    rename_map = {date_col: 'date'}\n\n    if target_col is not None:\n        ordered_cols.append(target_col)\n        rename_map[target_col] = target\n\n    df_prepared = df_raw[ordered_cols].rename(columns=rename_map)\n    return df_prepared\n\nclass Dataset_ETT_hour(Dataset):\n    def __init__(self, root_path, flag='train', size=None,\n                 features='S', data_path='ETTh1.csv',\n                 target='OT', scale=True, timeenc=0, freq='h'):\n        if size == None:\n            self.seq_len = 24 * 4 * 4\n            self.label_len = 24 * 4\n            self.pred_len = 24 * 4\n        else:\n            self.seq_len = size[0]\n            self.label_len = size[1]\n            self.pred_len = size[2]\n        assert flag in ['train', 'test', 'val']\n        type_map = {'train': 0, 'val': 1, 'test': 2}\n        self.set_type = type_map[flag]\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.timeenc = timeenc\n        self.freq = freq\n\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        df_raw = pd.read_csv(os.path.join(self.root_path,\n                                          self.data_path))\n\n        border1s = [0, 12 * 30 * 24 - self.seq_len, 12 * 30 * 24 + 4 * 30 * 24 - self.seq_len]\n        border2s = [12 * 30 * 24, 12 * 30 * 24 + 4 * 30 * 24, 12 * 30 * 24 + 8 * 30 * 24]\n        border1 = border1s[self.set_type]\n        border2 = border2s[self.set_type]\n\n        if self.features == 'M' or self.features == 'MS':\n            cols_data = df_raw.columns[1:]\n            df_data = df_raw[cols_data]\n        elif self.features == 'S':\n            df_data = df_raw[[self.target]]\n\n        if self.scale:\n            train_data = df_data[border1s[0]:border2s[0]]\n            self.scaler.fit(train_data.values)\n            data = self.scaler.transform(df_data.values)\n        else:\n            data = df_data.values\n\n        df_stamp = df_raw[['date']][border1:border2]\n        df_stamp['date'] = pd.to_datetime(df_stamp.date)\n        if self.timeenc == 0:\n            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)\n            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)\n            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)\n            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)\n            data_stamp = df_stamp.drop(['date'], 1).values\n        elif self.timeenc == 1:\n            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)\n            data_stamp = data_stamp.transpose(1, 0)\n\n        self.data_x = data[border1:border2]\n        self.data_y = data[border1:border2]\n        self.data_stamp = data_stamp\n\n    def __getitem__(self, index):\n        s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        seq_y = self.data_y[r_begin:r_end]\n        seq_x_mark = self.data_stamp[s_begin:s_end]\n        seq_y_mark = self.data_stamp[r_begin:r_end]\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        return len(self.data_x) - self.seq_len - self.pred_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n\n\nclass Dataset_ETT_minute(Dataset):\n    def __init__(self, root_path, flag='train', size=None,\n                 features='S', data_path='ETTm1.csv',\n                 target='OT', scale=True, timeenc=0, freq='t'):\n        if size == None:\n            self.seq_len = 24 * 4 * 4\n            self.label_len = 24 * 4\n            self.pred_len = 24 * 4\n        else:\n            self.seq_len = size[0]\n            self.label_len = size[1]\n            self.pred_len = size[2]\n        assert flag in ['train', 'test', 'val']\n        type_map = {'train': 0, 'val': 1, 'test': 2}\n        self.set_type = type_map[flag]\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.timeenc = timeenc\n        self.freq = freq\n\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        df_raw = pd.read_csv(os.path.join(self.root_path,\n                                          self.data_path))\n\n        border1s = [0, 12 * 30 * 24 * 4 - self.seq_len, 12 * 30 * 24 * 4 + 4 * 30 * 24 * 4 - self.seq_len]\n        border2s = [12 * 30 * 24 * 4, 12 * 30 * 24 * 4 + 4 * 30 * 24 * 4, 12 * 30 * 24 * 4 + 8 * 30 * 24 * 4]\n        border1 = border1s[self.set_type]\n        border2 = border2s[self.set_type]\n\n        if self.features == 'M' or self.features == 'MS':\n            cols_data = df_raw.columns[1:]\n            df_data = df_raw[cols_data]\n        elif self.features == 'S':\n            df_data = df_raw[[self.target]]\n\n        if self.scale:\n            train_data = df_data[border1s[0]:border2s[0]]\n            self.scaler.fit(train_data.values)\n            data = self.scaler.transform(df_data.values)\n        else:\n            data = df_data.values\n\n        df_stamp = df_raw[['date']][border1:border2]\n        df_stamp['date'] = pd.to_datetime(df_stamp.date)\n        if self.timeenc == 0:\n            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)\n            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)\n            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)\n            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)\n            df_stamp['minute'] = df_stamp.date.apply(lambda row: row.minute, 1)\n            df_stamp['minute'] = df_stamp.minute.map(lambda x: x // 15)\n            data_stamp = df_stamp.drop(['date'], 1).values\n        elif self.timeenc == 1:\n            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)\n            data_stamp = data_stamp.transpose(1, 0)\n\n        self.data_x = data[border1:border2]\n        self.data_y = data[border1:border2]\n        self.data_stamp = data_stamp\n\n    def __getitem__(self, index):\n        s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        seq_y = self.data_y[r_begin:r_end]\n        seq_x_mark = self.data_stamp[s_begin:s_end]\n        seq_y_mark = self.data_stamp[r_begin:r_end]\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        return len(self.data_x) - self.seq_len - self.pred_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n\n\nclass Dataset_Custom(Dataset):\n    def __init__(self, root_path, flag='train', size=None,\n                 features='S', data_path='ETTh1.csv',\n                 target='OT', scale=True, timeenc=0, freq='h'):\n        if size == None:\n            self.seq_len = 24 * 4 * 4\n            self.label_len = 24 * 4\n            self.pred_len = 24 * 4\n        else:\n            self.seq_len = size[0]\n            self.label_len = size[1]\n            self.pred_len = size[2]\n        assert flag in ['train', 'test', 'val']\n        type_map = {'train': 0, 'val': 1, 'test': 2}\n        self.set_type = type_map[flag]\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.timeenc = timeenc\n        self.freq = freq\n\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        df_raw = pd.read_csv(os.path.join(self.root_path,\n                                          self.data_path))\n        df_raw = _prepare_custom_dataframe(df_raw, self.target, self.features)\n        num_train = int(len(df_raw) * 0.7)\n        num_test = int(len(df_raw) * 0.2)\n        num_vali = len(df_raw) - num_train - num_test\n        border1s = [0, num_train - self.seq_len, len(df_raw) - num_test - self.seq_len]\n        border2s = [num_train, num_train + num_vali, len(df_raw)]\n        border1 = border1s[self.set_type]\n        border2 = border2s[self.set_type]\n\n        if self.features == 'M' or self.features == 'MS':\n            cols_data = df_raw.columns[1:]\n            df_data = df_raw[cols_data]\n        elif self.features == 'S':\n            df_data = df_raw[[self.target]]\n\n        if self.scale:\n            train_data = df_data[border1s[0]:border2s[0]]\n            self.scaler.fit(train_data.values)\n            data = self.scaler.transform(df_data.values)\n        else:\n            data = df_data.values\n\n        df_stamp = df_raw[['date']][border1:border2]\n        df_stamp['date'] = pd.to_datetime(df_stamp.date)\n        if self.timeenc == 0:\n            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)\n            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)\n            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)\n            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)\n            data_stamp = df_stamp.drop(['date'], 1).values\n        elif self.timeenc == 1:\n            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)\n            data_stamp = data_stamp.transpose(1, 0)\n\n        self.data_x = data[border1:border2]\n        self.data_y = data[border1:border2]\n        self.data_stamp = data_stamp\n\n    def __getitem__(self, index):\n        s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        seq_y = self.data_y[r_begin:r_end]\n        seq_x_mark = self.data_stamp[s_begin:s_end]\n        seq_y_mark = self.data_stamp[r_begin:r_end]\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        return len(self.data_x) - self.seq_len - self.pred_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n\n\nclass Dataset_PEMS(Dataset):\n    def __init__(self, root_path, flag='train', size=None,\n                 features='S', data_path='ETTh1.csv',\n                 target='OT', scale=True, timeenc=0, freq='h', seasonal_patterns=None):\n        self.seq_len = size[0]\n        self.label_len = size[1]\n        self.pred_len = size[2]\n        assert flag in ['train', 'test', 'val']\n        type_map = {'train': 0, 'val': 1, 'test': 2}\n        self.set_type = type_map[flag]\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.timeenc = timeenc\n        self.freq = freq\n\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        data_file = os.path.join(self.root_path, self.data_path)\n        print('data file:', data_file)\n        data = np.load(data_file, allow_pickle=True)\n        data = data['data'][:, :, 0]\n\n        train_ratio = 0.6\n        valid_ratio = 0.2\n        train_data = data[:int(train_ratio * len(data))]\n        valid_data = data[int(train_ratio * len(data)):int((train_ratio + valid_ratio) * len(data))]\n        test_data = data[int((train_ratio + valid_ratio) * len(data)):]\n        total_data = [train_data, valid_data, test_data]\n        data = total_data[self.set_type]\n\n        if self.scale:\n            self.scaler.fit(data)\n            data = self.scaler.transform(data)\n\n        df = pd.DataFrame(data)\n        df = df.fillna(method='ffill', limit=len(df)).fillna(method='bfill', limit=len(df)).values\n\n        self.data_x = df\n        self.data_y = df\n\n    def __getitem__(self, index):\n        if self.set_type == 2:  \n            s_begin = index * 12\n        else:\n            s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        seq_y = self.data_y[r_begin:r_end]\n        seq_x_mark = torch.zeros((seq_x.shape[0], 1))\n        seq_y_mark = torch.zeros((seq_y.shape[0], 1))\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        if self.set_type == 2: \n            return (len(self.data_x) - self.seq_len - self.pred_len + 1) // 12\n        else:\n            return len(self.data_x) - self.seq_len - self.pred_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n\n\nclass Dataset_Solar(Dataset):\n    def __init__(self, root_path, flag='train', size=None,\n                 features='S', data_path='ETTh1.csv',\n                 target='OT', scale=True, timeenc=0, freq='h'):\n        self.seq_len = size[0]\n        self.label_len = size[1]\n        self.pred_len = size[2]\n        assert flag in ['train', 'test', 'val']\n        type_map = {'train': 0, 'val': 1, 'test': 2}\n        self.set_type = type_map[flag]\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.timeenc = timeenc\n        self.freq = freq\n\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        df_raw = []\n        with open(os.path.join(self.root_path, self.data_path), \"r\", encoding='utf-8') as f:\n            for line in f.readlines():\n                line = line.strip('\\n').split(',')\n                data_line = np.stack([float(i) for i in line])\n                df_raw.append(data_line)\n        df_raw = np.stack(df_raw, 0)\n        df_raw = pd.DataFrame(df_raw)\n\n        num_train = int(len(df_raw) * 0.7)\n        num_test = int(len(df_raw) * 0.2)\n        num_valid = int(len(df_raw) * 0.1)\n        border1s = [0, num_train - self.seq_len, len(df_raw) - num_test - self.seq_len]\n        border2s = [num_train, num_train + num_valid, len(df_raw)]\n        border1 = border1s[self.set_type]\n        border2 = border2s[self.set_type]\n\n        df_data = df_raw.values\n\n        if self.scale:\n            train_data = df_data[border1s[0]:border2s[0]]\n            self.scaler.fit(train_data)\n            data = self.scaler.transform(df_data)\n        else:\n            data = df_data\n\n        self.data_x = data[border1:border2]\n        self.data_y = data[border1:border2]\n\n    def __getitem__(self, index):\n        s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        seq_y = self.data_y[r_begin:r_end]\n        seq_x_mark = torch.zeros((seq_x.shape[0], 1))\n        seq_y_mark = torch.zeros((seq_x.shape[0], 1))\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        return len(self.data_x) - self.seq_len - self.pred_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n\n\nclass Dataset_Pred(Dataset):\n    def __init__(self, root_path, flag='pred', size=None,\n                 features='S', data_path='ETTh1.csv',\n                 target='OT', scale=True, inverse=False, timeenc=0, freq='15min', cols=None):\n        if size == None:\n            self.seq_len = 24 * 4 * 4\n            self.label_len = 24 * 4\n            self.pred_len = 24 * 4\n        else:\n            self.seq_len = size[0]\n            self.label_len = size[1]\n            self.pred_len = size[2]\n        assert flag in ['pred']\n\n        self.features = features\n        self.target = target\n        self.scale = scale\n        self.inverse = inverse\n        self.timeenc = timeenc\n        self.freq = freq\n        self.cols = cols\n        self.root_path = root_path\n        self.data_path = data_path\n        self.__read_data__()\n\n    def __read_data__(self):\n        self.scaler = StandardScaler()\n        df_raw = pd.read_csv(os.path.join(self.root_path,\n                                          self.data_path))\n        df_raw = _prepare_custom_dataframe(df_raw, self.target, self.features)\n        if self.cols:\n            keep_cols = ['date']\n            keep_cols.extend([col for col in self.cols if col in df_raw.columns and col != 'date'])\n            if self.target in df_raw.columns and self.target not in keep_cols:\n                keep_cols.append(self.target)\n            df_raw = df_raw[keep_cols]\n        border1 = len(df_raw) - self.seq_len\n        border2 = len(df_raw)\n\n        if self.features == 'M' or self.features == 'MS':\n            cols_data = df_raw.columns[1:]\n            df_data = df_raw[cols_data]\n        elif self.features == 'S':\n            df_data = df_raw[[self.target]]\n\n        if self.scale:\n            self.scaler.fit(df_data.values)\n            data = self.scaler.transform(df_data.values)\n        else:\n            data = df_data.values\n\n        tmp_stamp = df_raw[['date']][border1:border2]\n        tmp_stamp['date'] = pd.to_datetime(tmp_stamp.date)\n        pred_dates = pd.date_range(tmp_stamp.date.values[-1], periods=self.pred_len + 1, freq=self.freq)\n\n        df_stamp = pd.DataFrame(columns=['date'])\n        df_stamp.date = list(tmp_stamp.date.values) + list(pred_dates[1:])\n        if self.timeenc == 0:\n            df_stamp['month'] = df_stamp.date.apply(lambda row: row.month, 1)\n            df_stamp['day'] = df_stamp.date.apply(lambda row: row.day, 1)\n            df_stamp['weekday'] = df_stamp.date.apply(lambda row: row.weekday(), 1)\n            df_stamp['hour'] = df_stamp.date.apply(lambda row: row.hour, 1)\n            df_stamp['minute'] = df_stamp.date.apply(lambda row: row.minute, 1)\n            df_stamp['minute'] = df_stamp.minute.map(lambda x: x // 15)\n            data_stamp = df_stamp.drop(['date'], 1).values\n        elif self.timeenc == 1:\n            data_stamp = time_features(pd.to_datetime(df_stamp['date'].values), freq=self.freq)\n            data_stamp = data_stamp.transpose(1, 0)\n\n        self.data_x = data[border1:border2]\n        if self.inverse:\n            self.data_y = df_data.values[border1:border2]\n        else:\n            self.data_y = data[border1:border2]\n        self.data_stamp = data_stamp\n\n    def __getitem__(self, index):\n        s_begin = index\n        s_end = s_begin + self.seq_len\n        r_begin = s_end - self.label_len\n        r_end = r_begin + self.label_len + self.pred_len\n\n        seq_x = self.data_x[s_begin:s_end]\n        if self.inverse:\n            seq_y = self.data_x[r_begin:r_begin + self.label_len]\n        else:\n            seq_y = self.data_y[r_begin:r_begin + self.label_len]\n        seq_x_mark = self.data_stamp[s_begin:s_end]\n        seq_y_mark = self.data_stamp[r_begin:r_end]\n\n        return seq_x, seq_y, seq_x_mark, seq_y_mark\n\n    def __len__(self):\n        return len(self.data_x) - self.seq_len + 1\n\n    def inverse_transform(self, data):\n        return self.scaler.inverse_transform(data)\n", "utils/metrics.py": "import numpy as np\n\n\nEPS = 1e-8\n\n\ndef RSE(pred, true):\n    numerator = np.sqrt(np.sum((true - pred) ** 2))\n    denominator = np.sqrt(np.sum((true - true.mean()) ** 2))\n    return numerator / (denominator + EPS)\n\n\ndef CORR(pred, true):\n    u = ((true - true.mean(0)) * (pred - pred.mean(0))).sum(0)\n    d = np.sqrt(((true - true.mean(0)) ** 2 * (pred - pred.mean(0)) ** 2).sum(0))\n    return (u / (d + EPS)).mean(-1)\n\n\ndef MAE(pred, true):\n    return np.mean(np.abs(pred - true))\n\n\ndef MSE(pred, true):\n    return np.mean((pred - true) ** 2)\n\n\ndef RMSE(pred, true):\n    return np.sqrt(MSE(pred, true))\n\n# Troubleshooting for PEMS Nov 8\n# def MAPE(pred, true):\n#     return np.mean(np.abs((pred - true) / true))\ndef MAPE(pred, true):\n    mape = np.abs((pred - true) / (true + EPS))\n    mape = np.where(mape > 5, 0, mape)\n    return np.mean(mape)\n\n\ndef MSPE(pred, true):\n    return np.mean(np.square((pred - true) / (true + EPS)))\n\n\ndef SMAPE(pred, true):\n    denominator = np.abs(pred) + np.abs(true) + EPS\n    return np.mean(2.0 * np.abs(pred - true) / denominator)\n\n\ndef WAPE(pred, true):\n    return np.sum(np.abs(pred - true)) / (np.sum(np.abs(true)) + EPS)\n\n\ndef R2(pred, true):\n    ss_res = np.sum((true - pred) ** 2)\n    ss_tot = np.sum((true - np.mean(true)) ** 2)\n    return 1.0 - (ss_res / (ss_tot + EPS))\n\n\ndef metric(pred, true):\n    mae = MAE(pred, true)\n    mse = MSE(pred, true)\n    rmse = RMSE(pred, true)\n    mape = MAPE(pred, true)\n    mspe = MSPE(pred, true)\n\n    return mae, mse, rmse, mape, mspe\n\n\ndef metric_extended(pred, true):\n    mae, mse, rmse, mape, mspe = metric(pred, true)\n    rse = RSE(pred, true)\n    corr = CORR(pred, true)\n    smape = SMAPE(pred, true)\n    wape = WAPE(pred, true)\n    r2 = R2(pred, true)\n\n    if isinstance(corr, np.ndarray):\n        corr = float(np.mean(corr))\n\n    return {\n        'mae': float(mae),\n        'mse': float(mse),\n        'rmse': float(rmse),\n        'mape': float(mape),\n        'mspe': float(mspe),\n        'rse': float(rse),\n        'corr': float(corr),\n        'smape': float(smape),\n        'wape': float(wape),\n        'r2': float(r2),\n    }\n", "experiments/exp_long_term_forecasting.py": "from torch.optim import lr_scheduler\n\nfrom data_provider.data_factory import data_provider\nfrom experiments.exp_basic import Exp_Basic\nfrom utils.tools import EarlyStopping, adjust_learning_rate, visual\nfrom utils.metrics import metric, metric_extended\nimport torch\nimport torch.nn as nn\nfrom torch import optim\nimport os\nimport time\nimport warnings\nimport numpy as np\n\nwarnings.filterwarnings('ignore')\n\ntorch.autograd.set_detect_anomaly(True)\n\n\nclass Exp_Long_Term_Forecast(Exp_Basic):\n    def __init__(self, args):\n        super(Exp_Long_Term_Forecast, self).__init__(args)\n\n    def _build_model(self):\n        model = self.model_dict[self.args.model].Model(self.args).float()\n\n        if self.args.use_multi_gpu and self.args.use_gpu:\n            model = nn.DataParallel(model, device_ids=self.args.device_ids)        #wrapper for using multiple gpu\n        return model\n\n    def _get_data(self, flag):\n        data_set, data_loader = data_provider(self.args, flag)\n        return data_set, data_loader\n\n    def _select_optimizer(self):\n        model_optim = optim.AdamW(self.model.parameters(), lr=self.args.learning_rate)\n        return model_optim\n\n    def _select_criterion(self):\n        if self.args.data == 'PEMS':\n            criterion = nn.L1Loss()  #Mean Absolute Error\n        else:\n            criterion = nn.MSELoss() #Mean Squared Error\n        return criterion\n\n    def vali(self, vali_data, vali_loader, criterion):\n        total_loss = []\n        self.model.eval()\n        with torch.no_grad():    #Disables gradient computation.\n            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(vali_loader):\n                batch_x = batch_x.float().to(self.device)\n                batch_y = batch_y.float()\n\n                if 'PEMS' in self.args.data or 'Solar' in self.args.data:\n                    batch_x_mark = None\n                    batch_y_mark = None\n                else:\n                    batch_x_mark = batch_x_mark.float().to(self.device)\n                    batch_y_mark = batch_y_mark.float().to(self.device)\n\n                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float() #creates a tensor of zeros that has the same shape as the future part of batch_y.\n                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device) #cat is concatinate\n\n                if self.args.use_amp:        #Automatic Mixed Precision (AMP) is a technique in deep learning that uses both 32-bit and 16-bit floating point numbers during training to make training faster and use less GPU memory, while keeping model accuracy.\n                    with torch.cuda.amp.autocast():\n                        if self.args.output_attention:\n                            outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                        else:\n                            outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                else:\n                    if self.args.output_attention:\n                        outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                    else:\n                        outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                f_dim = -1 if self.args.features == 'MS' else 0\n                outputs = outputs[:, -self.args.pred_len:, f_dim:] # in this  --self.args.pred_len is done only for safty\n                batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)\n\n                pred = outputs.detach().cpu() #detach() is used to remove the tensor from the computation graph.\n                true = batch_y.detach().cpu() #cpu() is used to move the tensor from the GPU to the CPU.\n\n                if self.args.data == 'PEMS':\n                    B, T, C = pred.shape\n                    pred = pred.numpy()\n                    true = true.numpy()\n                    pred = vali_data.inverse_transform(pred.reshape(-1, C)).reshape(B, T, C)\n                    true = vali_data.inverse_transform(true.reshape(-1, C)).reshape(B, T, C)\n                    mae, mse, rmse, mape, mspe = metric(pred, true)\n                    total_loss.append(mae)\n                else:\n                    loss = criterion(pred, true)\n                    total_loss.append(loss)\n\n        total_loss = np.average(total_loss)\n        self.model.train()\n        return total_loss\n\n    def train(self, setting):      #start again from here\n        train_data, train_loader = self._get_data(flag='train')\n        vali_data, vali_loader = self._get_data(flag='val')\n        test_data, test_loader = self._get_data(flag='test')\n\n        path = os.path.join(self.args.checkpoints, setting)\n        if not os.path.exists(path):\n            os.makedirs(path)\n\n        time_now = time.time()\n\n        train_steps = len(train_loader)\n        early_stopping = EarlyStopping(patience=self.args.patience, verbose=True)\n\n        model_optim = self._select_optimizer()\n        criterion = self._select_criterion()\n\n        if self.args.lradj == 'TST':\n            scheduler = lr_scheduler.OneCycleLR(optimizer=model_optim,\n                                                steps_per_epoch=train_steps,\n                                                pct_start=self.args.pct_start,\n                                                epochs=self.args.train_epochs,\n                                                max_lr=self.args.learning_rate)\n\n\n        if self.args.use_amp:\n            scaler = torch.cuda.amp.GradScaler()\n        # # Efficiency: dynamic memory footprint\n        # # Track dynamic memory usage over an epoch\n        # torch.cuda.reset_peak_memory_stats()  # Reset peak memory tracking\n\n        for epoch in range(self.args.train_epochs):\n            iter_count = 0\n            train_loss = []\n\n            self.model.train()\n            epoch_time = time.time()\n            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(train_loader):\n                iter_count += 1\n                model_optim.zero_grad()\n                batch_x = batch_x.float().to(self.device)\n\n                batch_y = batch_y.float().to(self.device)\n                if 'PEMS' in self.args.data or 'Solar' in self.args.data:\n                    batch_x_mark = None\n                    batch_y_mark = None\n                else:\n                    batch_x_mark = batch_x_mark.float().to(self.device)\n                    batch_y_mark = batch_y_mark.float().to(self.device)\n\n                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()\n                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)\n\n                if self.args.use_amp:\n                    with torch.cuda.amp.autocast():\n                        if self.args.output_attention:\n                            outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                        else:\n                            outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n\n                        f_dim = -1 if self.args.features == 'MS' else 0\n                        outputs = outputs[:, -self.args.pred_len:, f_dim:]\n                        batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)\n                        loss = criterion(outputs, batch_y) \n                        train_loss.append(loss.item())\n                else:\n                    if self.args.output_attention:\n                        outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                    else:\n                        outputs, attn = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n\n                    f_dim = -1 if self.args.features == 'MS' else 0                        \n                    outputs = outputs[:, -self.args.pred_len:, f_dim:]\n                    batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)\n                    \n                    loss = criterion(outputs, batch_y) + self.args.l1_weight * attn[0] \n                    train_loss.append(loss.item())\n\n                if (i + 1) % 30 == 0:\n                    print(\"\\titers: {0}, epoch: {1} | loss: {2:.7f}\".format(i + 1, epoch + 1, loss.item()))\n                    speed = (time.time() - time_now) / iter_count\n                    left_time = speed * ((self.args.train_epochs - epoch) * train_steps - i)\n                    print('\\tspeed: {:.4f}s/iter; left time: {:.4f}s'.format(speed, left_time))\n                    iter_count = 0\n                    time_now = time.time()\n\n                if self.args.use_amp:\n                    scaler.scale(loss).backward()\n                    scaler.step(model_optim)\n                    scaler.update()\n                else:\n                    loss.backward()\n                    model_optim.step()\n                    # # Efficiency: dynamic memory footprint\n                    # # Record current and peak memory usage after processing this batch\n                    # current_memory = torch.cuda.memory_allocated()\n                    # peak_memory = torch.cuda.max_memory_allocated()\n                    # print(f\"Current memory: {current_memory / (1024 ** 2):.2f} MB, Peak memory: {peak_memory / (1024 ** 2):.2f} MB\")\n\n                if self.args.lradj == 'TST':\n                    adjust_learning_rate(model_optim, epoch + 1, self.args, scheduler, printout=False)\n                    scheduler.step()\n\n\n            print(\"Epoch: {} cost time: {}\".format(epoch + 1, time.time() - epoch_time))\n            train_loss = np.average(train_loss)\n            vali_loss = self.vali(vali_data, vali_loader, criterion)\n            test_loss = self.vali(test_data, test_loader, criterion)\n\n            print(\"Epoch: {0}, Steps: {1} | Train Loss: {2:.7f} Vali Loss: {3:.7f} Test Loss: {4:.7f}\".format(\n                epoch + 1, train_steps, train_loss, vali_loss, test_loss))\n            early_stopping(vali_loss, self.model, path)\n            if early_stopping.early_stop:\n                print(\"Early stopping\")\n                break\n\n            if self.args.lradj != 'TST':\n                adjust_learning_rate(model_optim, epoch + 1, self.args)\n            else:\n                adjust_learning_rate(model_optim, epoch + 1, self.args, scheduler)\n\n        \n        best_model_path = path + '/' + 'checkpoint.pth'\n        self.model.load_state_dict(torch.load(best_model_path))\n\n        return self.model\n\n    def test(self, setting, test=0):\n        test_data, test_loader = self._get_data(flag='test')\n        if test:\n            print('loading model')\n            self.model.load_state_dict(torch.load(os.path.join('./checkpoints/' + setting, 'checkpoint.pth')))\n\n        preds = []\n        trues = []\n        folder_path = './checkpoints/' + setting + '/'\n        if not os.path.exists(folder_path):\n            os.makedirs(folder_path)\n\n        self.model.eval()\n        with torch.no_grad():\n            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(test_loader):\n                batch_x = batch_x.float().to(self.device)\n                batch_y = batch_y.float().to(self.device)\n\n                if 'PEMS' in self.args.data or 'Solar' in self.args.data:\n                    batch_x_mark = None\n                    batch_y_mark = None\n                else:\n                    batch_x_mark = batch_x_mark.float().to(self.device)\n                    batch_y_mark = batch_y_mark.float().to(self.device)\n\n\n                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()\n                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)\n                # encoder - decoder\n                if self.args.use_amp:\n                    with torch.cuda.amp.autocast():\n                        if self.args.output_attention:\n                            outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                        else:\n                            outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                else:\n                    if self.args.output_attention:\n                        outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                    else:\n                        outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n\n                f_dim = -1 if self.args.features == 'MS' else 0\n                outputs = outputs[:, -self.args.pred_len:, f_dim:]\n                batch_y = batch_y[:, -self.args.pred_len:, f_dim:].to(self.device)\n                outputs = outputs.detach().cpu().numpy()\n                batch_y = batch_y.detach().cpu().numpy()\n\n                pred = outputs\n                true = batch_y\n\n                preds.append(pred)\n                trues.append(true)\n                if i % 20 == 0:\n                    input = batch_x.detach().cpu().numpy()\n                    if test_data.scale and self.args.inverse:\n                        shape = input.shape\n                        input = test_data.inverse_transform(input.squeeze(0)).reshape(shape)\n                    gt = np.concatenate((input[0, :, -1], true[0, :, -1]), axis=0)\n                    pd = np.concatenate((input[0, :, -1], pred[0, :, -1]), axis=0)\n                    visual(gt, pd, os.path.join(folder_path, str(i) + '.pdf'))\n\n        preds = np.array(preds)\n        trues = np.array(trues)\n        print('test shape:', preds.shape, trues.shape)\n        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])\n        trues = trues.reshape(-1, trues.shape[-2], trues.shape[-1])\n        print('test shape:', preds.shape, trues.shape)\n\n        if self.args.data == 'PEMS':\n            B, T, C = preds.shape\n            preds = test_data.inverse_transform(preds.reshape(-1, C)).reshape(B, T, C)\n            trues = test_data.inverse_transform(trues.reshape(-1, C)).reshape(B, T, C)\n\n        # result save\n        folder_path = './checkpoints/' + setting + '/'\n        if not os.path.exists(folder_path):\n            os.makedirs(folder_path)\n\n        metrics = metric_extended(preds, trues)\n        print('mse:{}, mae:{}'.format(metrics['mse'], metrics['mae']))\n        print('rmse:{}, mape:{}, mspe:{}'.format(metrics['rmse'], metrics['mape'], metrics['mspe']))\n        print(\n            'rse:{}, corr:{}, smape:{}, wape:{}, r2:{}'.format(\n                metrics['rse'],\n                metrics['corr'],\n                metrics['smape'],\n                metrics['wape'],\n                metrics['r2'],\n            )\n        )\n        f = open(\"result_long_term_forecast.txt\", 'a')\n        f.write(setting + \"  \\n\")\n        metric_parts = [f'{name}:{value}' for name, value in metrics.items()]\n        f.write(', '.join(metric_parts))\n        f.write('\\n')\n        f.write('\\n')\n        f.close()\n\n    \n        return\n\n\n    def predict(self, setting, load=False):\n        pred_data, pred_loader = self._get_data(flag='pred')\n\n        if load:\n            path = os.path.join(self.args.checkpoints, setting)\n            best_model_path = path + '/' + 'checkpoint.pth'\n            self.model.load_state_dict(torch.load(best_model_path))\n\n        preds = []\n\n        self.model.eval()\n        with torch.no_grad():\n            for i, (batch_x, batch_y, batch_x_mark, batch_y_mark) in enumerate(pred_loader):\n                batch_x = batch_x.float().to(self.device)\n                batch_y = batch_y.float()\n                batch_x_mark = batch_x_mark.float().to(self.device)\n                batch_y_mark = batch_y_mark.float().to(self.device)\n\n    \n                dec_inp = torch.zeros_like(batch_y[:, -self.args.pred_len:, :]).float()\n                dec_inp = torch.cat([batch_y[:, :self.args.label_len, :], dec_inp], dim=1).float().to(self.device)\n                # encoder - decoder\n                if self.args.use_amp:\n                    with torch.cuda.amp.autocast():\n                        if self.args.output_attention:\n                            outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                        else:\n                            outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                else:\n                    if self.args.output_attention:\n                        outputs = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                    else:\n                        outputs, _ = self.model(batch_x, batch_x_mark, dec_inp, batch_y_mark)\n                outputs = outputs.detach().cpu().numpy()\n                if pred_data.scale and self.args.inverse:\n                    shape = outputs.shape\n                    outputs = pred_data.inverse_transform(outputs.squeeze(0)).reshape(shape)\n                preds.append(outputs)\n\n        preds = np.array(preds)\n        preds = preds.reshape(-1, preds.shape[-2], preds.shape[-1])\n\n        # result save\n        folder_path = './results/' + setting + '/'\n        if not os.path.exists(folder_path):\n            os.makedirs(folder_path)\n\n        np.save(folder_path + 'real_prediction.npy', preds)\n\n        return\n"}

for rel_path, content in FILES_TO_SYNC.items():
    abs_path = os.path.join(REPO_DIR, rel_path)
    os.makedirs(os.path.dirname(abs_path), exist_ok=True)
    with open(abs_path, 'w', encoding='utf-8', newline='') as f:
        f.write(content)
    print(f"Synced {rel_path}")

# !sed -i 's/np\.Inf/np.inf/g' {REPO_DIR}/utils/tools.py
print("Repo sync complete.")
# Out:
# Synced run.py
# Synced model/SimpleTM.py
# Synced model/SimpleTM_SWT.py
# Synced model/SimpleTM_FFT.py
# Synced layers/ParallelAttention_Family.py
# Synced data_provider/data_loader.py
# Synced utils/metrics.py
# Synced experiments/exp_long_term_forecasting.py
# Repo sync complete.

# %%
FILE_ID = "1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR"
OUTPUT_PATH = "/kaggle/working/dataset.zip"
DATASET_DIR = "./dataset"

if not os.path.exists(DATASET_DIR):
    # !gdown https://drive.google.com/uc?id={FILE_ID} -O {OUTPUT_PATH}
    import zipfile
    os.makedirs(DATASET_DIR, exist_ok=True)
    with zipfile.ZipFile(OUTPUT_PATH, 'r') as zip_ref:
        zip_ref.extractall(DATASET_DIR)
    print("Dataset extracted successfully.")
else:
    print("Dataset already exists.")

for root, dirs, files in os.walk(DATASET_DIR):
    level = root.replace(DATASET_DIR, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    subindent = ' ' * 2 * (level + 1)
    for file in files[:10]:
        print(f'{subindent}{file}')
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR
# From (redirected): https://drive.google.com/uc?id=1JOgmL2ntyxKg6eB132ytCbVZumiHnDLR&confirm=t&uuid=810e9488-6bd3-4f75-ac82-3372379517c5
# To: /kaggle/working/dataset.zip
# 100%|████████████████████████████████████████| 172M/172M [00:03<00:00, 52.6MB/s]
# Dataset extracted successfully.
# dataset/
#   __MACOSX/
#     ._SimpleTM_datasets
#     SimpleTM_datasets/
#       ._ETT-small
#       ._Solar
#       ._PEMS
#       ._electricity
#       ._weather
#       ._traffic
#       ._.DS_Store
#       weather/
#         ._weather.csv
#       PEMS/
#         ._PEMS04.npz
#         ._PEMS08.npz
#         ._PEMS07.npz
#         ._PEMS03.npz
#       electricity/
#         ._electricity.csv
#         ._.DS_Store
#       Solar/
#         ._solar_AL.txt
#       ETT-small/
#         ._ETTm1.csv
#         ._ETTh1.csv
#         ._ETTh2.csv
#         ._ETTm2.csv
#       traffic/
#         ._.DS_Store
#         ._traffic.csv
#   SimpleTM_datasets/
#     .DS_Store
#     weather/
#       weather.csv
#     PEMS/
#       PEMS08.npz
#       PEMS07.npz
#       PEMS03.npz
#       PEMS04.npz
#     electricity/
#       .DS_Store
#       electricity.csv
#     smartbuilding/
#       smart.csv
#     Solar/
#       solar_AL.txt
#     ETT-small/
#       ETTh1.csv
#       ETTm2.csv
#       ETTh2.csv
#       ETTm1.csv
#     traffic/
#       .DS_Store
#       traffic.csv

# %%
# smart_candidates = [
#     ("./dataset/SimpleTM_datasets/smartbuilding", "smart.csv"),
#     ("./dataset/SimpleTM_datasets/Smartbuilding", "smart.csv"),
#     (".", "smart.csv"),
# ]

# SMART_ROOT, SMART_PATH = None, None
# for root, path in smart_candidates:
#     candidate = os.path.join(root, path)
#     if os.path.exists(candidate):
#         SMART_ROOT, SMART_PATH = root, path
#         break

# if SMART_ROOT is None:
#     raise FileNotFoundError("smart.csv not found in the extracted dataset or repo root.")

# smart_df = pd.read_csv(os.path.join(SMART_ROOT, SMART_PATH))
# print("smart.csv shape:", smart_df.shape)
# print("smart.csv columns:")
# for i, col in enumerate(smart_df.columns, start=1):
#     print(f"{i:02d}. {col}")
# print() 
# print(smart_df.head(3).to_string())

# %%
SELECTED_DATASETS = None
# Example: SELECTED_DATASETS = ["ETTh1", "Solar", "smartbuilding"]

all_datasets = [
    {"name": "ETTh1", "data": "ETTh1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h"},
    # {"name": "ETTh2", "data": "ETTh2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTh2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h"},
    {"name": "ETTm1", "data": "ETTm1", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm1.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "t"},
    # {"name": "ETTm2", "data": "ETTm2", "root": "./dataset/SimpleTM_datasets/ETT-small", "path": "ETTm2.csv", "enc_in": 7, "d_model": 32, "d_ff": 32, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "t"},
    {"name": "weather", "data": "custom", "root": "./dataset/SimpleTM_datasets/weather", "path": "weather.csv", "enc_in": 21, "d_model": 32, "d_ff": 32, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h"},
    {"name": "electricity", "data": "custom", "root": "./dataset/SimpleTM_datasets/electricity", "path": "electricity.csv", "enc_in": 321, "d_model": 128, "d_ff": 128, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h"},
    {"name": "traffic", "data": "custom", "root": "./dataset/SimpleTM_datasets/traffic", "path": "traffic.csv", "enc_in": 862, "d_model": 256, "d_ff": 256, "wv": "db1", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 8, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h"},
    {"name": "Solar", "data": "Solar", "root": "./dataset/SimpleTM_datasets/Solar", "path": "solar_AL.txt", "enc_in": 137, "d_model": 128, "d_ff": 256, "wv": "db8", "m": 3, "alpha": 0.0, "learning_rate": 0.003, "batch_size": 128, "train_epochs": 10, "patience": 3, "use_norm": 0, "lradj": "TST", "freq": "h"},
    {"name": "PEMS03", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS03.npz", "enc_in": 358, "d_model": 256, "d_ff": 1024, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h"},
    # {"name": "PEMS04", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS04.npz", "enc_in": 307, "d_model": 256, "d_ff": 1024, "wv": "bior3.1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h"},
    # {"name": "PEMS07", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS07.npz", "enc_in": 883, "d_model": 256, "d_ff": 512, "wv": "db1", "m": 3, "alpha": 0.1, "learning_rate": 0.002, "batch_size": 8, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h"},
    # {"name": "PEMS08", "data": "PEMS", "root": "./dataset/SimpleTM_datasets/PEMS", "path": "PEMS08.npz", "enc_in": 170, "d_model": 256, "d_ff": 1024, "wv": "db12", "m": 3, "alpha": 0.0, "learning_rate": 0.001, "batch_size": 16, "train_epochs": 20, "patience": 10, "use_norm": 0, "lradj": "TST", "freq": "h"},
    {"name": "smartbuilding", "data": "custom", "root": "./dataset/SimpleTM_datasets/smartbuilding", "path": "smart.csv", "enc_in": 37, "d_model": 64, "d_ff": 128, "wv": "db4", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h", "target": "Floor_Total(kW)"},
    # {"name": "smartbuilding", "data": "custom", "root": SMART_ROOT, "path": SMART_PATH, "enc_in": 37, "d_model": 64, "d_ff": 128, "wv": "db4", "m": 3, "alpha": 1.0, "learning_rate": 0.0001, "batch_size": 32, "train_epochs": 10, "patience": 3, "use_norm": 1, "lradj": "type1", "freq": "h", "target": "Floor_Total(kW)"},
]

experiments = [
    {"tag": "SWT_original", "model": "SimpleTM_SWT", "attention_mode": "original"},
    {"tag": "SWT_dual", "model": "SimpleTM_SWT", "attention_mode": "dual"},
    {"tag": "FFT_original", "model": "SimpleTM_FFT", "attention_mode": "original"},
    {"tag": "FFT_dual", "model": "SimpleTM_FFT", "attention_mode": "dual"},
]

if SELECTED_DATASETS is not None:
    datasets = [ds for ds in all_datasets if ds["name"] in SELECTED_DATASETS]
else:
    datasets = all_datasets

datasets = [ds for ds in datasets if os.path.exists(os.path.join(ds["root"], ds["path"]))]

OUTPUT_DIR = "/kaggle/working/SimpleTM_AllDatasets_Smart_Results"

if os.path.exists(OUTPUT_DIR):
    shutil.rmtree(OUTPUT_DIR)
if os.path.exists("./checkpoints"):
    shutil.rmtree("./checkpoints")
if os.path.exists("result_long_term_forecast.txt"):
    os.remove("result_long_term_forecast.txt")

os.makedirs(OUTPUT_DIR, exist_ok=True)
os.makedirs(f"{OUTPUT_DIR}/plots", exist_ok=True)

run_plan = pd.DataFrame(datasets)
run_plan.to_csv(os.path.join(OUTPUT_DIR, "run_plan.csv"), index=False)
print(run_plan[["name", "data", "path", "enc_in", "d_model", "d_ff"]].to_string(index=False))
print(f"\nDatasets: {len(datasets)}")
print(f"Variants per dataset: {len(experiments)}")
print(f"Total runs planned: {len(datasets) * len(experiments)}")
# Out:
#          name   data            path  enc_in  d_model  d_ff
#         ETTh1  ETTh1       ETTh1.csv       7       32    32
#         ETTm1  ETTm1       ETTm1.csv       7       32    32
#       weather custom     weather.csv      21       32    32
#   electricity custom electricity.csv     321      128   128
#       traffic custom     traffic.csv     862      256   256
#         Solar  Solar    solar_AL.txt     137      128   256
#        PEMS03   PEMS      PEMS03.npz     358      256  1024
# smartbuilding custom       smart.csv      37       64   128
#
# Datasets: 8
# Variants per dataset: 4
# Total runs planned: 32

# %%
for ds in datasets:
    print("\n" + "=" * 100)
    print(f"DATASET: {ds['name']} | variates={ds['enc_in']}")
    print("=" * 100 + "\n")

    for exp in experiments:
        print(f">>> Training {exp['tag']} on {ds['name']} <<<\n")
        unique_model_id = f"{ds['name']}_{exp['model']}_{exp['attention_mode']}"

        cmd = [
            "python", "-u", "run.py",
            "--is_training", "1",
            "--model", exp["model"],
            "--attention_mode", exp["attention_mode"],
            "--model_id", unique_model_id,
            "--data", ds["data"],
            "--root_path", ds["root"],
            "--data_path", ds["path"],
            "--features", "M",
            "--freq", ds["freq"],
            "--seq_len", "96",
            "--pred_len", "96",
            "--e_layers", "1",
            "--d_model", str(ds["d_model"]),
            "--d_ff", str(ds["d_ff"]),
            "--enc_in", str(ds["enc_in"]),
            "--dec_in", str(ds["enc_in"]),
            "--c_out", str(ds["enc_in"]),
            "--wv", ds["wv"],
            "--m", str(ds["m"]),
            "--alpha", str(ds["alpha"]),
            "--learning_rate", str(ds["learning_rate"]),
            "--batch_size", str(ds["batch_size"]),
            "--train_epochs", str(ds["train_epochs"]),
            "--patience", str(ds["patience"]),
            "--num_workers", "2",
            "--lradj", ds["lradj"],
            "--use_norm", str(ds["use_norm"]),
            "--checkpoints", f"{OUTPUT_DIR}/checkpoints/",
            "--fix_seed", "2025"
        ]

        if "target" in ds:
            cmd.extend(["--target", ds["target"]])

        process = subprocess.Popen(
            cmd,
            stdout=subprocess.PIPE,
            stderr=subprocess.STDOUT,
            text=True,
        )
        for line in process.stdout:
            print(line, end="")
        process.wait()

        if process.returncode == 0:
            print(f"\nSUCCESS: Finished {exp['tag']} on {ds['name']}\n")
        else:
            raise RuntimeError(f"Run failed for {ds['name']} | {exp['tag']} with exit code {process.returncode}")

print("\nGathering generated PDF plots...")
if os.path.exists('./checkpoints'):
    for root_dir, dirs, files in os.walk('./checkpoints'):
        for file in files:
            if file.endswith('.pdf'):
                folder_name = os.path.basename(root_dir)
                source_path = os.path.join(root_dir, file)
                target_plot_dir = os.path.join(OUTPUT_DIR, 'plots', folder_name)
                os.makedirs(target_plot_dir, exist_ok=True)
                shutil.copy(source_path, os.path.join(target_plot_dir, file))
    print(f"Copied PDF plots to {OUTPUT_DIR}/plots/")

if os.path.exists('result_long_term_forecast.txt'):
    shutil.copy('result_long_term_forecast.txt', os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt'))
    print("Copied metric text results to output directory.")
# Out:
# ====================================================================================================
# DATASET: ETTh1 | variates=7
# ====================================================================================================
#
# >>> Training SWT_original on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_SWT_original', model='SimpleTM_SWT', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 12856
# Memory usage for trainable parameters: 0.05 MB
# Static memory footprint (allocated): 0.06 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.6559232
# 	speed: 0.1080s/iter; left time: 282.0512s
# 	iters: 60, epoch: 1 | loss: 0.6726899
# 	speed: 0.0682s/iter; left time: 176.0582s
# 	iters: 90, epoch: 1 | loss: 0.5831890
# 	speed: 0.0707s/iter; left time: 180.3631s
# 	iters: 120, epoch: 1 | loss: 0.5076125
# 	speed: 0.0755s/iter; left time: 190.2726s
# 	iters: 150, epoch: 1 | loss: 0.5493618
# 	speed: 0.0676s/iter; left time: 168.5139s
# 	iters: 180, epoch: 1 | loss: 0.5446462
# 	speed: 0.0670s/iter; left time: 165.0030s
# 	iters: 210, epoch: 1 | loss: 0.4428372
# 	speed: 0.0664s/iter; left time: 161.4319s
# 	iters: 240, epoch: 1 | loss: 0.5381377
# 	speed: 0.0675s/iter; left time: 162.1716s
# Epoch: 1 cost time: 19.356420516967773
# Epoch: 1, Steps: 264 | Train Loss: 0.5616698 Vali Loss: 0.9440508 Test Loss: 0.5550969
# Validation loss decreased (inf --> 0.944051).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.5219585
# 	speed: 0.1658s/iter; left time: 389.1847s
# 	iters: 60, epoch: 2 | loss: 0.4837210
# 	speed: 0.0665s/iter; left time: 154.1010s
# 	iters: 90, epoch: 2 | loss: 0.5258867
# 	speed: 0.0692s/iter; left time: 158.2381s
# 	iters: 120, epoch: 2 | loss: 0.4635446
# 	speed: 0.0663s/iter; left time: 149.6299s
# 	iters: 150, epoch: 2 | loss: 0.4995888
# 	speed: 0.0657s/iter; left time: 146.2598s
# 	iters: 180, epoch: 2 | loss: 0.3637263
# 	speed: 0.0655s/iter; left time: 143.9321s
# 	iters: 210, epoch: 2 | loss: 0.4712696
# 	speed: 0.0663s/iter; left time: 143.7418s
# 	iters: 240, epoch: 2 | loss: 0.3966441
# 	speed: 0.0680s/iter; left time: 145.3044s
# Epoch: 2 cost time: 17.671185970306396
# Epoch: 2, Steps: 264 | Train Loss: 0.4592940 Vali Loss: 0.8397101 Test Loss: 0.4815858
# Validation loss decreased (0.944051 --> 0.839710).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.4287069
# 	speed: 0.1661s/iter; left time: 346.0128s
# 	iters: 60, epoch: 3 | loss: 0.4760068
# 	speed: 0.0672s/iter; left time: 138.0587s
# 	iters: 90, epoch: 3 | loss: 0.4365045
# 	speed: 0.0674s/iter; left time: 136.2725s
# 	iters: 120, epoch: 3 | loss: 0.4032339
# 	speed: 0.0686s/iter; left time: 136.7023s
# 	iters: 150, epoch: 3 | loss: 0.4289300
# 	speed: 0.0673s/iter; left time: 132.0710s
# 	iters: 180, epoch: 3 | loss: 0.4346679
# 	speed: 0.0665s/iter; left time: 128.4935s
# 	iters: 210, epoch: 3 | loss: 0.4264302
# 	speed: 0.0654s/iter; left time: 124.3887s
# 	iters: 240, epoch: 3 | loss: 0.4476362
# 	speed: 0.0658s/iter; left time: 123.2587s
# Epoch: 3 cost time: 17.73060393333435
# Epoch: 3, Steps: 264 | Train Loss: 0.4337917 Vali Loss: 0.8119823 Test Loss: 0.4654031
# Validation loss decreased (0.839710 --> 0.811982).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.4711557
# 	speed: 0.1648s/iter; left time: 299.8218s
# 	iters: 60, epoch: 4 | loss: 0.4471381
# 	speed: 0.0662s/iter; left time: 118.4729s
# 	iters: 90, epoch: 4 | loss: 0.4146998
# 	speed: 0.0660s/iter; left time: 116.0076s
# 	iters: 120, epoch: 4 | loss: 0.4288814
# 	speed: 0.0680s/iter; left time: 117.5511s
# 	iters: 150, epoch: 4 | loss: 0.3894029
# 	speed: 0.0656s/iter; left time: 111.5338s
# 	iters: 180, epoch: 4 | loss: 0.3613643
# 	speed: 0.0657s/iter; left time: 109.6611s
# 	iters: 210, epoch: 4 | loss: 0.3511804
# 	speed: 0.0654s/iter; left time: 107.1932s
# 	iters: 240, epoch: 4 | loss: 0.3571965
# 	speed: 0.0664s/iter; left time: 106.7775s
# Epoch: 4 cost time: 17.57001829147339
# Epoch: 4, Steps: 264 | Train Loss: 0.4259644 Vali Loss: 0.8006727 Test Loss: 0.4582431
# Validation loss decreased (0.811982 --> 0.800673).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.4234315
# 	speed: 0.1659s/iter; left time: 257.9146s
# 	iters: 60, epoch: 5 | loss: 0.4523326
# 	speed: 0.0668s/iter; left time: 101.9245s
# 	iters: 90, epoch: 5 | loss: 0.3999636
# 	speed: 0.0673s/iter; left time: 100.5499s
# 	iters: 120, epoch: 5 | loss: 0.4203108
# 	speed: 0.0670s/iter; left time: 98.1966s
# 	iters: 150, epoch: 5 | loss: 0.4062009
# 	speed: 0.0683s/iter; left time: 98.0553s
# 	iters: 180, epoch: 5 | loss: 0.4553178
# 	speed: 0.0655s/iter; left time: 92.0910s
# 	iters: 210, epoch: 5 | loss: 0.4333642
# 	speed: 0.0661s/iter; left time: 90.9238s
# 	iters: 240, epoch: 5 | loss: 0.4281853
# 	speed: 0.0660s/iter; left time: 88.7164s
# Epoch: 5 cost time: 17.669708967208862
# Epoch: 5, Steps: 264 | Train Loss: 0.4221315 Vali Loss: 0.7950948 Test Loss: 0.4547555
# Validation loss decreased (0.800673 --> 0.795095).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.4376090
# 	speed: 0.1657s/iter; left time: 213.9006s
# 	iters: 60, epoch: 6 | loss: 0.4803029
# 	speed: 0.0664s/iter; left time: 83.6778s
# 	iters: 90, epoch: 6 | loss: 0.4053299
# 	speed: 0.0663s/iter; left time: 81.6385s
# 	iters: 120, epoch: 6 | loss: 0.3922083
# 	speed: 0.0681s/iter; left time: 81.7753s
# 	iters: 150, epoch: 6 | loss: 0.3742625
# 	speed: 0.0694s/iter; left time: 81.2917s
# 	iters: 180, epoch: 6 | loss: 0.4030765
# 	speed: 0.0657s/iter; left time: 75.0156s
# 	iters: 210, epoch: 6 | loss: 0.4847686
# 	speed: 0.0659s/iter; left time: 73.2192s
# 	iters: 240, epoch: 6 | loss: 0.3716035
# 	speed: 0.0667s/iter; left time: 72.0593s
# Epoch: 6 cost time: 17.686482667922974
# Epoch: 6, Steps: 264 | Train Loss: 0.4201663 Vali Loss: 0.7922640 Test Loss: 0.4529647
# Validation loss decreased (0.795095 --> 0.792264).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.4590041
# 	speed: 0.1679s/iter; left time: 172.4097s
# 	iters: 60, epoch: 7 | loss: 0.4159078
# 	speed: 0.0653s/iter; left time: 65.1167s
# 	iters: 90, epoch: 7 | loss: 0.4736105
# 	speed: 0.0655s/iter; left time: 63.3813s
# 	iters: 120, epoch: 7 | loss: 0.4378439
# 	speed: 0.0661s/iter; left time: 61.9219s
# 	iters: 150, epoch: 7 | loss: 0.3476543
# 	speed: 0.0677s/iter; left time: 61.3821s
# 	iters: 180, epoch: 7 | loss: 0.4368058
# 	speed: 0.0677s/iter; left time: 59.3585s
# 	iters: 210, epoch: 7 | loss: 0.3548914
# 	speed: 0.0665s/iter; left time: 56.2885s
# 	iters: 240, epoch: 7 | loss: 0.4480393
# 	speed: 0.0664s/iter; left time: 54.2400s
# Epoch: 7 cost time: 17.652756690979004
# Epoch: 7, Steps: 264 | Train Loss: 0.4192982 Vali Loss: 0.7902997 Test Loss: 0.4520634
# Validation loss decreased (0.792264 --> 0.790300).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.4244688
# 	speed: 0.1649s/iter; left time: 125.8295s
# 	iters: 60, epoch: 8 | loss: 0.4324281
# 	speed: 0.0668s/iter; left time: 48.9618s
# 	iters: 90, epoch: 8 | loss: 0.3359299
# 	speed: 0.0675s/iter; left time: 47.4372s
# 	iters: 120, epoch: 8 | loss: 0.4381087
# 	speed: 0.0680s/iter; left time: 45.7412s
# 	iters: 150, epoch: 8 | loss: 0.5100746
# 	speed: 0.0673s/iter; left time: 43.2567s
# 	iters: 180, epoch: 8 | loss: 0.3905976
# 	speed: 0.0693s/iter; left time: 42.4572s
# 	iters: 210, epoch: 8 | loss: 0.4406060
# 	speed: 0.0701s/iter; left time: 40.8400s
# 	iters: 240, epoch: 8 | loss: 0.3895647
# 	speed: 0.0667s/iter; left time: 36.8682s
# Epoch: 8 cost time: 17.99933123588562
# Epoch: 8, Steps: 264 | Train Loss: 0.4187786 Vali Loss: 0.7900924 Test Loss: 0.4516068
# Validation loss decreased (0.790300 --> 0.790092).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.3673579
# 	speed: 0.1648s/iter; left time: 82.2233s
# 	iters: 60, epoch: 9 | loss: 0.4809181
# 	speed: 0.0687s/iter; left time: 32.2381s
# 	iters: 90, epoch: 9 | loss: 0.4371126
# 	speed: 0.0686s/iter; left time: 30.1183s
# 	iters: 120, epoch: 9 | loss: 0.4805813
# 	speed: 0.0683s/iter; left time: 27.9298s
# 	iters: 150, epoch: 9 | loss: 0.4751576
# 	speed: 0.0673s/iter; left time: 25.5241s
# 	iters: 180, epoch: 9 | loss: 0.3574999
# 	speed: 0.0671s/iter; left time: 23.4173s
# 	iters: 210, epoch: 9 | loss: 0.3938679
# 	speed: 0.0680s/iter; left time: 21.6811s
# 	iters: 240, epoch: 9 | loss: 0.4152335
# 	speed: 0.0667s/iter; left time: 19.2635s
# Epoch: 9 cost time: 17.911682605743408
# Epoch: 9, Steps: 264 | Train Loss: 0.4185623 Vali Loss: 0.7898771 Test Loss: 0.4513766
# Validation loss decreased (0.790092 --> 0.789877).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.3918905
# 	speed: 0.1670s/iter; left time: 39.2448s
# 	iters: 60, epoch: 10 | loss: 0.4681030
# 	speed: 0.0691s/iter; left time: 14.1748s
# 	iters: 90, epoch: 10 | loss: 0.4318790
# 	speed: 0.0653s/iter; left time: 11.4290s
# 	iters: 120, epoch: 10 | loss: 0.4087418
# 	speed: 0.0649s/iter; left time: 9.4163s
# 	iters: 150, epoch: 10 | loss: 0.4520253
# 	speed: 0.0660s/iter; left time: 7.5877s
# 	iters: 180, epoch: 10 | loss: 0.3970161
# 	speed: 0.0660s/iter; left time: 5.6060s
# 	iters: 210, epoch: 10 | loss: 0.4860061
# 	speed: 0.0675s/iter; left time: 3.7144s
# 	iters: 240, epoch: 10 | loss: 0.4388674
# 	speed: 0.0650s/iter; left time: 1.6248s
# Epoch: 10 cost time: 17.562641382217407
# Epoch: 10, Steps: 264 | Train Loss: 0.4185595 Vali Loss: 0.7892676 Test Loss: 0.4512585
# Validation loss decreased (0.789877 --> 0.789268).  Saving model ...
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : ETTh1_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.4512585699558258, mae:0.44616246223449707
# rmse:0.6717578172683716, mape:0.7282772064208984, mspe:42734.98046875
# rse:0.6380673050880432, corr:25.48047637939453, smape:0.819637656211853, wape:0.5605157017707825, r2:0.5928701162338257
#
# SUCCESS: Finished SWT_original on ETTh1
#
# >>> Training SWT_dual on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_SWT_dual', model='SimpleTM_SWT', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 15193
# Memory usage for trainable parameters: 0.06 MB
# Static memory footprint (allocated): 0.07 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.7879989
# 	speed: 0.1044s/iter; left time: 272.5649s
# 	iters: 60, epoch: 1 | loss: 0.6591519
# 	speed: 0.0880s/iter; left time: 227.1741s
# 	iters: 90, epoch: 1 | loss: 0.4596994
# 	speed: 0.0836s/iter; left time: 213.1726s
# 	iters: 120, epoch: 1 | loss: 0.5169074
# 	speed: 0.0908s/iter; left time: 228.9167s
# 	iters: 150, epoch: 1 | loss: 0.5754160
# 	speed: 0.0849s/iter; left time: 211.4601s
# 	iters: 180, epoch: 1 | loss: 0.4814337
# 	speed: 0.0872s/iter; left time: 214.5846s
# 	iters: 210, epoch: 1 | loss: 0.6007756
# 	speed: 0.0844s/iter; left time: 205.2194s
# 	iters: 240, epoch: 1 | loss: 0.4985250
# 	speed: 0.0847s/iter; left time: 203.3413s
# Epoch: 1 cost time: 23.355705499649048
# Epoch: 1, Steps: 264 | Train Loss: 0.5650063 Vali Loss: 0.9443826 Test Loss: 0.5552112
# Validation loss decreased (inf --> 0.944383).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.4493230
# 	speed: 0.2071s/iter; left time: 485.9791s
# 	iters: 60, epoch: 2 | loss: 0.4359885
# 	speed: 0.0846s/iter; left time: 196.0817s
# 	iters: 90, epoch: 2 | loss: 0.4937499
# 	speed: 0.0848s/iter; left time: 193.8321s
# 	iters: 120, epoch: 2 | loss: 0.3890703
# 	speed: 0.0851s/iter; left time: 192.0101s
# 	iters: 150, epoch: 2 | loss: 0.3647449
# 	speed: 0.0850s/iter; left time: 189.2872s
# 	iters: 180, epoch: 2 | loss: 0.4054743
# 	speed: 0.0835s/iter; left time: 183.5461s
# 	iters: 210, epoch: 2 | loss: 0.4465807
# 	speed: 0.0854s/iter; left time: 184.9657s
# 	iters: 240, epoch: 2 | loss: 0.4415700
# 	speed: 0.0845s/iter; left time: 180.6779s
# Epoch: 2 cost time: 22.491819381713867
# Epoch: 2, Steps: 264 | Train Loss: 0.4564446 Vali Loss: 0.8331653 Test Loss: 0.4776081
# Validation loss decreased (0.944383 --> 0.833165).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.4497890
# 	speed: 0.2017s/iter; left time: 420.0932s
# 	iters: 60, epoch: 3 | loss: 0.4201340
# 	speed: 0.0841s/iter; left time: 172.7119s
# 	iters: 90, epoch: 3 | loss: 0.3994186
# 	speed: 0.0860s/iter; left time: 173.9024s
# 	iters: 120, epoch: 3 | loss: 0.4784024
# 	speed: 0.0827s/iter; left time: 164.8043s
# 	iters: 150, epoch: 3 | loss: 0.4538782
# 	speed: 0.0838s/iter; left time: 164.5295s
# 	iters: 180, epoch: 3 | loss: 0.4382857
# 	speed: 0.0829s/iter; left time: 160.3212s
# 	iters: 210, epoch: 3 | loss: 0.4753950
# 	speed: 0.0851s/iter; left time: 161.9058s
# 	iters: 240, epoch: 3 | loss: 0.4019796
# 	speed: 0.0834s/iter; left time: 156.1559s
# Epoch: 3 cost time: 22.238322496414185
# Epoch: 3, Steps: 264 | Train Loss: 0.4302092 Vali Loss: 0.8051962 Test Loss: 0.4607805
# Validation loss decreased (0.833165 --> 0.805196).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.4115053
# 	speed: 0.2002s/iter; left time: 364.1429s
# 	iters: 60, epoch: 4 | loss: 0.4542532
# 	speed: 0.0869s/iter; left time: 155.4248s
# 	iters: 90, epoch: 4 | loss: 0.4519858
# 	speed: 0.0836s/iter; left time: 147.0868s
# 	iters: 120, epoch: 4 | loss: 0.4144182
# 	speed: 0.0843s/iter; left time: 145.7455s
# 	iters: 150, epoch: 4 | loss: 0.4340259
# 	speed: 0.0843s/iter; left time: 143.1908s
# 	iters: 180, epoch: 4 | loss: 0.4473065
# 	speed: 0.0864s/iter; left time: 144.1328s
# 	iters: 210, epoch: 4 | loss: 0.4574794
# 	speed: 0.0841s/iter; left time: 137.9118s
# 	iters: 240, epoch: 4 | loss: 0.3614647
# 	speed: 0.0833s/iter; left time: 134.0477s
# Epoch: 4 cost time: 22.38419771194458
# Epoch: 4, Steps: 264 | Train Loss: 0.4220570 Vali Loss: 0.7926993 Test Loss: 0.4535182
# Validation loss decreased (0.805196 --> 0.792699).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.4051809
# 	speed: 0.2016s/iter; left time: 313.5574s
# 	iters: 60, epoch: 5 | loss: 0.3522592
# 	speed: 0.0840s/iter; left time: 128.0243s
# 	iters: 90, epoch: 5 | loss: 0.3887789
# 	speed: 0.0835s/iter; left time: 124.8492s
# 	iters: 120, epoch: 5 | loss: 0.4327732
# 	speed: 0.0864s/iter; left time: 126.5959s
# 	iters: 150, epoch: 5 | loss: 0.4786243
# 	speed: 0.0843s/iter; left time: 120.9204s
# 	iters: 180, epoch: 5 | loss: 0.4160156
# 	speed: 0.0843s/iter; left time: 118.4536s
# 	iters: 210, epoch: 5 | loss: 0.4284893
# 	speed: 0.0845s/iter; left time: 116.1295s
# 	iters: 240, epoch: 5 | loss: 0.4102888
# 	speed: 0.0861s/iter; left time: 115.7975s
# Epoch: 5 cost time: 22.37691020965576
# Epoch: 5, Steps: 264 | Train Loss: 0.4184355 Vali Loss: 0.7879315 Test Loss: 0.4499463
# Validation loss decreased (0.792699 --> 0.787932).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.4114978
# 	speed: 0.2030s/iter; left time: 262.0298s
# 	iters: 60, epoch: 6 | loss: 0.4473560
# 	speed: 0.0870s/iter; left time: 109.7578s
# 	iters: 90, epoch: 6 | loss: 0.3827021
# 	speed: 0.0849s/iter; left time: 104.4884s
# 	iters: 120, epoch: 6 | loss: 0.4008192
# 	speed: 0.0856s/iter; left time: 102.7572s
# 	iters: 150, epoch: 6 | loss: 0.3969779
# 	speed: 0.0843s/iter; left time: 98.7532s
# 	iters: 180, epoch: 6 | loss: 0.3965656
# 	speed: 0.0868s/iter; left time: 98.9864s
# 	iters: 210, epoch: 6 | loss: 0.3567136
# 	speed: 0.0853s/iter; left time: 94.7251s
# 	iters: 240, epoch: 6 | loss: 0.4091317
# 	speed: 0.0852s/iter; left time: 92.0571s
# Epoch: 6 cost time: 22.62306785583496
# Epoch: 6, Steps: 264 | Train Loss: 0.4168146 Vali Loss: 0.7850981 Test Loss: 0.4481680
# Validation loss decreased (0.787932 --> 0.785098).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.3642251
# 	speed: 0.2100s/iter; left time: 215.7129s
# 	iters: 60, epoch: 7 | loss: 0.4477606
# 	speed: 0.0841s/iter; left time: 83.8624s
# 	iters: 90, epoch: 7 | loss: 0.3948491
# 	speed: 0.0855s/iter; left time: 82.6500s
# 	iters: 120, epoch: 7 | loss: 0.4285738
# 	speed: 0.0845s/iter; left time: 79.1555s
# 	iters: 150, epoch: 7 | loss: 0.4099957
# 	speed: 0.0852s/iter; left time: 77.2424s
# 	iters: 180, epoch: 7 | loss: 0.3875870
# 	speed: 0.0838s/iter; left time: 73.4565s
# 	iters: 210, epoch: 7 | loss: 0.4072787
# 	speed: 0.0842s/iter; left time: 71.3114s
# 	iters: 240, epoch: 7 | loss: 0.4276702
# 	speed: 0.0841s/iter; left time: 68.7092s
# Epoch: 7 cost time: 22.562371969223022
# Epoch: 7, Steps: 264 | Train Loss: 0.4156556 Vali Loss: 0.7837167 Test Loss: 0.4472538
# Validation loss decreased (0.785098 --> 0.783717).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.4756974
# 	speed: 0.2010s/iter; left time: 153.3431s
# 	iters: 60, epoch: 8 | loss: 0.4155087
# 	speed: 0.0853s/iter; left time: 62.5076s
# 	iters: 90, epoch: 8 | loss: 0.3791457
# 	speed: 0.0866s/iter; left time: 60.8656s
# 	iters: 120, epoch: 8 | loss: 0.4200297
# 	speed: 0.0863s/iter; left time: 58.0610s
# 	iters: 150, epoch: 8 | loss: 0.4381270
# 	speed: 0.0851s/iter; left time: 54.7029s
# 	iters: 180, epoch: 8 | loss: 0.4011256
# 	speed: 0.0853s/iter; left time: 52.2687s
# 	iters: 210, epoch: 8 | loss: 0.4240516
# 	speed: 0.0874s/iter; left time: 50.9560s
# 	iters: 240, epoch: 8 | loss: 0.3909839
# 	speed: 0.0844s/iter; left time: 46.6499s
# Epoch: 8 cost time: 22.636986255645752
# Epoch: 8, Steps: 264 | Train Loss: 0.4152319 Vali Loss: 0.7830950 Test Loss: 0.4468005
# Validation loss decreased (0.783717 --> 0.783095).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.4080179
# 	speed: 0.2023s/iter; left time: 100.9427s
# 	iters: 60, epoch: 9 | loss: 0.4290172
# 	speed: 0.0870s/iter; left time: 40.8227s
# 	iters: 90, epoch: 9 | loss: 0.3473923
# 	speed: 0.0851s/iter; left time: 37.3761s
# 	iters: 120, epoch: 9 | loss: 0.4058100
# 	speed: 0.0858s/iter; left time: 35.0871s
# 	iters: 150, epoch: 9 | loss: 0.4132946
# 	speed: 0.0845s/iter; left time: 32.0150s
# 	iters: 180, epoch: 9 | loss: 0.4222876
# 	speed: 0.0855s/iter; left time: 29.8496s
# 	iters: 210, epoch: 9 | loss: 0.3800952
# 	speed: 0.0853s/iter; left time: 27.2132s
# 	iters: 240, epoch: 9 | loss: 0.3453876
# 	speed: 0.0867s/iter; left time: 25.0429s
# Epoch: 9 cost time: 22.695098400115967
# Epoch: 9, Steps: 264 | Train Loss: 0.4151105 Vali Loss: 0.7827500 Test Loss: 0.4465684
# Validation loss decreased (0.783095 --> 0.782750).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.4397058
# 	speed: 0.2082s/iter; left time: 48.9213s
# 	iters: 60, epoch: 10 | loss: 0.3931613
# 	speed: 0.0854s/iter; left time: 17.4979s
# 	iters: 90, epoch: 10 | loss: 0.3878433
# 	speed: 0.0846s/iter; left time: 14.8001s
# 	iters: 120, epoch: 10 | loss: 0.5142826
# 	speed: 0.0878s/iter; left time: 12.7338s
# 	iters: 150, epoch: 10 | loss: 0.3467312
# 	speed: 0.0851s/iter; left time: 9.7834s
# 	iters: 180, epoch: 10 | loss: 0.4106432
# 	speed: 0.0852s/iter; left time: 7.2400s
# 	iters: 210, epoch: 10 | loss: 0.3661564
# 	speed: 0.0836s/iter; left time: 4.5999s
# 	iters: 240, epoch: 10 | loss: 0.4794339
# 	speed: 0.0860s/iter; left time: 2.1507s
# Epoch: 10 cost time: 22.590949773788452
# Epoch: 10, Steps: 264 | Train Loss: 0.4149147 Vali Loss: 0.7820225 Test Loss: 0.4464521
# Validation loss decreased (0.782750 --> 0.782022).  Saving model ...
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : ETTh1_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.44645217061042786, mae:0.4436003565788269
# rmse:0.6681707501411438, mape:0.7237409949302673, mspe:41538.265625
# rse:0.6346601843833923, corr:25.52732276916504, smape:0.8185407519340515, wape:0.5572969317436218, r2:0.5972064733505249
#
# SUCCESS: Finished SWT_dual on ETTh1
#
# >>> Training FFT_original on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_FFT_original', model='SimpleTM_FFT', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 12808
# Memory usage for trainable parameters: 0.05 MB
# Static memory footprint (allocated): 0.05 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.6617748
# 	speed: 0.0773s/iter; left time: 201.9308s
# 	iters: 60, epoch: 1 | loss: 0.6791621
# 	speed: 0.0498s/iter; left time: 128.4309s
# 	iters: 90, epoch: 1 | loss: 0.5894639
# 	speed: 0.0499s/iter; left time: 127.3959s
# 	iters: 120, epoch: 1 | loss: 0.5153849
# 	speed: 0.0496s/iter; left time: 125.0390s
# 	iters: 150, epoch: 1 | loss: 0.5533341
# 	speed: 0.0507s/iter; left time: 126.2505s
# 	iters: 180, epoch: 1 | loss: 0.5452569
# 	speed: 0.0502s/iter; left time: 123.4527s
# 	iters: 210, epoch: 1 | loss: 0.4426490
# 	speed: 0.0494s/iter; left time: 120.0252s
# 	iters: 240, epoch: 1 | loss: 0.5429041
# 	speed: 0.0491s/iter; left time: 117.8461s
# Epoch: 1 cost time: 14.00858211517334
# Epoch: 1, Steps: 264 | Train Loss: 0.5672616 Vali Loss: 0.9617007 Test Loss: 0.5663064
# Validation loss decreased (inf --> 0.961701).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.5252658
# 	speed: 0.1403s/iter; left time: 329.3793s
# 	iters: 60, epoch: 2 | loss: 0.4855702
# 	speed: 0.0498s/iter; left time: 115.4316s
# 	iters: 90, epoch: 2 | loss: 0.5264051
# 	speed: 0.0491s/iter; left time: 112.3155s
# 	iters: 120, epoch: 2 | loss: 0.4661458
# 	speed: 0.0477s/iter; left time: 107.7256s
# 	iters: 150, epoch: 2 | loss: 0.5030441
# 	speed: 0.0487s/iter; left time: 108.5001s
# 	iters: 180, epoch: 2 | loss: 0.3647638
# 	speed: 0.0480s/iter; left time: 105.4063s
# 	iters: 210, epoch: 2 | loss: 0.4669824
# 	speed: 0.0478s/iter; left time: 103.6616s
# 	iters: 240, epoch: 2 | loss: 0.3990768
# 	speed: 0.0492s/iter; left time: 105.1378s
# Epoch: 2 cost time: 12.91895318031311
# Epoch: 2, Steps: 264 | Train Loss: 0.4609827 Vali Loss: 0.8534731 Test Loss: 0.4873025
# Validation loss decreased (0.961701 --> 0.853473).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.4278833
# 	speed: 0.1378s/iter; left time: 287.0818s
# 	iters: 60, epoch: 3 | loss: 0.4730006
# 	speed: 0.0491s/iter; left time: 100.7509s
# 	iters: 90, epoch: 3 | loss: 0.4386435
# 	speed: 0.0485s/iter; left time: 98.1760s
# 	iters: 120, epoch: 3 | loss: 0.4025068
# 	speed: 0.0492s/iter; left time: 97.9939s
# 	iters: 150, epoch: 3 | loss: 0.4292496
# 	speed: 0.0505s/iter; left time: 99.1808s
# 	iters: 180, epoch: 3 | loss: 0.4290447
# 	speed: 0.0488s/iter; left time: 94.3090s
# 	iters: 210, epoch: 3 | loss: 0.4259385
# 	speed: 0.0482s/iter; left time: 91.6889s
# 	iters: 240, epoch: 3 | loss: 0.4455420
# 	speed: 0.0489s/iter; left time: 91.5900s
# Epoch: 3 cost time: 12.955310583114624
# Epoch: 3, Steps: 264 | Train Loss: 0.4349968 Vali Loss: 0.8257861 Test Loss: 0.4708249
# Validation loss decreased (0.853473 --> 0.825786).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.4705437
# 	speed: 0.1390s/iter; left time: 252.8501s
# 	iters: 60, epoch: 4 | loss: 0.4481059
# 	speed: 0.0505s/iter; left time: 90.2838s
# 	iters: 90, epoch: 4 | loss: 0.4147387
# 	speed: 0.0486s/iter; left time: 85.4996s
# 	iters: 120, epoch: 4 | loss: 0.4275312
# 	speed: 0.0486s/iter; left time: 84.0423s
# 	iters: 150, epoch: 4 | loss: 0.3916592
# 	speed: 0.0493s/iter; left time: 83.6801s
# 	iters: 180, epoch: 4 | loss: 0.3615901
# 	speed: 0.0490s/iter; left time: 81.7473s
# 	iters: 210, epoch: 4 | loss: 0.3527350
# 	speed: 0.0480s/iter; left time: 78.6647s
# 	iters: 240, epoch: 4 | loss: 0.3584169
# 	speed: 0.0482s/iter; left time: 77.5835s
# Epoch: 4 cost time: 12.996080160140991
# Epoch: 4, Steps: 264 | Train Loss: 0.4273462 Vali Loss: 0.8146038 Test Loss: 0.4638327
# Validation loss decreased (0.825786 --> 0.814604).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.4300929
# 	speed: 0.1405s/iter; left time: 218.4546s
# 	iters: 60, epoch: 5 | loss: 0.4547457
# 	speed: 0.0484s/iter; left time: 73.8667s
# 	iters: 90, epoch: 5 | loss: 0.4053731
# 	speed: 0.0494s/iter; left time: 73.7980s
# 	iters: 120, epoch: 5 | loss: 0.4179384
# 	speed: 0.0487s/iter; left time: 71.3915s
# 	iters: 150, epoch: 5 | loss: 0.4072589
# 	speed: 0.0482s/iter; left time: 69.1021s
# 	iters: 180, epoch: 5 | loss: 0.4546701
# 	speed: 0.0506s/iter; left time: 71.1317s
# 	iters: 210, epoch: 5 | loss: 0.4346899
# 	speed: 0.0483s/iter; left time: 66.3934s
# 	iters: 240, epoch: 5 | loss: 0.4327199
# 	speed: 0.0484s/iter; left time: 65.1528s
# Epoch: 5 cost time: 12.972042560577393
# Epoch: 5, Steps: 264 | Train Loss: 0.4237672 Vali Loss: 0.8089862 Test Loss: 0.4604755
# Validation loss decreased (0.814604 --> 0.808986).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.4413089
# 	speed: 0.1387s/iter; left time: 179.0286s
# 	iters: 60, epoch: 6 | loss: 0.4776888
# 	speed: 0.0485s/iter; left time: 61.1848s
# 	iters: 90, epoch: 6 | loss: 0.4091677
# 	speed: 0.0506s/iter; left time: 62.2759s
# 	iters: 120, epoch: 6 | loss: 0.3899219
# 	speed: 0.0481s/iter; left time: 57.7470s
# 	iters: 150, epoch: 6 | loss: 0.3764906
# 	speed: 0.0478s/iter; left time: 55.9603s
# 	iters: 180, epoch: 6 | loss: 0.4053435
# 	speed: 0.0476s/iter; left time: 54.3229s
# 	iters: 210, epoch: 6 | loss: 0.4850402
# 	speed: 0.0488s/iter; left time: 54.2103s
# 	iters: 240, epoch: 6 | loss: 0.3737506
# 	speed: 0.0491s/iter; left time: 53.1098s
# Epoch: 6 cost time: 12.93657660484314
# Epoch: 6, Steps: 264 | Train Loss: 0.4217712 Vali Loss: 0.8061104 Test Loss: 0.4587463
# Validation loss decreased (0.808986 --> 0.806110).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.4594096
# 	speed: 0.1409s/iter; left time: 144.6879s
# 	iters: 60, epoch: 7 | loss: 0.4197181
# 	speed: 0.0488s/iter; left time: 48.6162s
# 	iters: 90, epoch: 7 | loss: 0.4729855
# 	speed: 0.0486s/iter; left time: 47.0092s
# 	iters: 120, epoch: 7 | loss: 0.4405268
# 	speed: 0.0491s/iter; left time: 46.0001s
# 	iters: 150, epoch: 7 | loss: 0.3498927
# 	speed: 0.0491s/iter; left time: 44.5002s
# 	iters: 180, epoch: 7 | loss: 0.4387057
# 	speed: 0.0492s/iter; left time: 43.1762s
# 	iters: 210, epoch: 7 | loss: 0.3554812
# 	speed: 0.0501s/iter; left time: 42.4452s
# 	iters: 240, epoch: 7 | loss: 0.4510859
# 	speed: 0.0480s/iter; left time: 39.2222s
# Epoch: 7 cost time: 13.007318258285522
# Epoch: 7, Steps: 264 | Train Loss: 0.4210699 Vali Loss: 0.8041341 Test Loss: 0.4578730
# Validation loss decreased (0.806110 --> 0.804134).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.4273756
# 	speed: 0.1455s/iter; left time: 111.0247s
# 	iters: 60, epoch: 8 | loss: 0.4327461
# 	speed: 0.0474s/iter; left time: 34.7603s
# 	iters: 90, epoch: 8 | loss: 0.3353767
# 	speed: 0.0484s/iter; left time: 33.9931s
# 	iters: 120, epoch: 8 | loss: 0.4421224
# 	speed: 0.0505s/iter; left time: 33.9685s
# 	iters: 150, epoch: 8 | loss: 0.5141655
# 	speed: 0.0491s/iter; left time: 31.5778s
# 	iters: 180, epoch: 8 | loss: 0.3923510
# 	speed: 0.0503s/iter; left time: 30.8152s
# 	iters: 210, epoch: 8 | loss: 0.4457670
# 	speed: 0.0494s/iter; left time: 28.7942s
# 	iters: 240, epoch: 8 | loss: 0.3940324
# 	speed: 0.0485s/iter; left time: 26.8244s
# Epoch: 8 cost time: 13.227090835571289
# Epoch: 8, Steps: 264 | Train Loss: 0.4204963 Vali Loss: 0.8039172 Test Loss: 0.4574306
# Validation loss decreased (0.804134 --> 0.803917).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.3652798
# 	speed: 0.1409s/iter; left time: 70.3053s
# 	iters: 60, epoch: 9 | loss: 0.4763860
# 	speed: 0.0485s/iter; left time: 22.7349s
# 	iters: 90, epoch: 9 | loss: 0.4394045
# 	speed: 0.0489s/iter; left time: 21.4670s
# 	iters: 120, epoch: 9 | loss: 0.4839953
# 	speed: 0.0482s/iter; left time: 19.7192s
# 	iters: 150, epoch: 9 | loss: 0.4754269
# 	speed: 0.0485s/iter; left time: 18.3989s
# 	iters: 180, epoch: 9 | loss: 0.3607690
# 	speed: 0.0488s/iter; left time: 17.0161s
# 	iters: 210, epoch: 9 | loss: 0.3957907
# 	speed: 0.0491s/iter; left time: 15.6642s
# 	iters: 240, epoch: 9 | loss: 0.4237222
# 	speed: 0.0509s/iter; left time: 14.6991s
# Epoch: 9 cost time: 13.051372289657593
# Epoch: 9, Steps: 264 | Train Loss: 0.4204443 Vali Loss: 0.8037021 Test Loss: 0.4572068
# Validation loss decreased (0.803917 --> 0.803702).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.3932039
# 	speed: 0.1398s/iter; left time: 32.8517s
# 	iters: 60, epoch: 10 | loss: 0.4741825
# 	speed: 0.0482s/iter; left time: 9.8811s
# 	iters: 90, epoch: 10 | loss: 0.4366714
# 	speed: 0.0481s/iter; left time: 8.4132s
# 	iters: 120, epoch: 10 | loss: 0.4146977
# 	speed: 0.0500s/iter; left time: 7.2490s
# 	iters: 150, epoch: 10 | loss: 0.4554586
# 	speed: 0.0487s/iter; left time: 5.6018s
# 	iters: 180, epoch: 10 | loss: 0.4007903
# 	speed: 0.0488s/iter; left time: 4.1443s
# 	iters: 210, epoch: 10 | loss: 0.4857669
# 	speed: 0.0485s/iter; left time: 2.6648s
# 	iters: 240, epoch: 10 | loss: 0.4420708
# 	speed: 0.0491s/iter; left time: 1.2278s
# Epoch: 10 cost time: 12.954953670501709
# Epoch: 10, Steps: 264 | Train Loss: 0.4202063 Vali Loss: 0.8030792 Test Loss: 0.4570913
# Validation loss decreased (0.803702 --> 0.803079).  Saving model ...
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : ETTh1_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.45709124207496643, mae:0.449468731880188
# rmse:0.6760852336883545, mape:0.731739342212677, mspe:40936.01171875
# rse:0.6421777009963989, corr:25.51835823059082, smape:0.8265496492385864, wape:0.5646694302558899, r2:0.5876078009605408
#
# SUCCESS: Finished FFT_original on ETTh1
#
# >>> Training FFT_dual on ETTh1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTh1_SimpleTM_FFT_dual', model='SimpleTM_FFT', data='ETTh1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTh1.csv', features='M', target='OT', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 15145
# Memory usage for trainable parameters: 0.06 MB
# Static memory footprint (allocated): 0.07 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTh1_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 8449
# val 2785
# test 2785
# 	iters: 30, epoch: 1 | loss: 0.7842126
# 	speed: 0.0846s/iter; left time: 220.8442s
# 	iters: 60, epoch: 1 | loss: 0.6546144
# 	speed: 0.0658s/iter; left time: 169.8185s
# 	iters: 90, epoch: 1 | loss: 0.4587467
# 	speed: 0.0634s/iter; left time: 161.7068s
# 	iters: 120, epoch: 1 | loss: 0.5161573
# 	speed: 0.0629s/iter; left time: 158.5720s
# 	iters: 150, epoch: 1 | loss: 0.5731980
# 	speed: 0.0638s/iter; left time: 158.9616s
# 	iters: 180, epoch: 1 | loss: 0.4808798
# 	speed: 0.0635s/iter; left time: 156.2285s
# 	iters: 210, epoch: 1 | loss: 0.6041049
# 	speed: 0.0645s/iter; left time: 156.8417s
# 	iters: 240, epoch: 1 | loss: 0.5001227
# 	speed: 0.0638s/iter; left time: 153.2510s
# Epoch: 1 cost time: 17.52133011817932
# Epoch: 1, Steps: 264 | Train Loss: 0.5642266 Vali Loss: 0.9563682 Test Loss: 0.5612671
# Validation loss decreased (inf --> 0.956368).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.4507602
# 	speed: 0.1679s/iter; left time: 393.9763s
# 	iters: 60, epoch: 2 | loss: 0.4374805
# 	speed: 0.0632s/iter; left time: 146.5272s
# 	iters: 90, epoch: 2 | loss: 0.4968841
# 	speed: 0.0748s/iter; left time: 171.0227s
# 	iters: 120, epoch: 2 | loss: 0.3909459
# 	speed: 0.0644s/iter; left time: 145.4154s
# 	iters: 150, epoch: 2 | loss: 0.3660667
# 	speed: 0.0647s/iter; left time: 144.1011s
# 	iters: 180, epoch: 2 | loss: 0.4084617
# 	speed: 0.0641s/iter; left time: 140.8690s
# 	iters: 210, epoch: 2 | loss: 0.4472121
# 	speed: 0.0639s/iter; left time: 138.5253s
# 	iters: 240, epoch: 2 | loss: 0.4476816
# 	speed: 0.0648s/iter; left time: 138.4187s
# Epoch: 2 cost time: 17.30509328842163
# Epoch: 2, Steps: 264 | Train Loss: 0.4583842 Vali Loss: 0.8446054 Test Loss: 0.4811399
# Validation loss decreased (0.956368 --> 0.844605).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.4530641
# 	speed: 0.1726s/iter; left time: 359.4311s
# 	iters: 60, epoch: 3 | loss: 0.4213897
# 	speed: 0.0648s/iter; left time: 132.9855s
# 	iters: 90, epoch: 3 | loss: 0.3995932
# 	speed: 0.0646s/iter; left time: 130.7300s
# 	iters: 120, epoch: 3 | loss: 0.4806935
# 	speed: 0.0653s/iter; left time: 130.2111s
# 	iters: 150, epoch: 3 | loss: 0.4560838
# 	speed: 0.0645s/iter; left time: 126.5708s
# 	iters: 180, epoch: 3 | loss: 0.4402274
# 	speed: 0.0646s/iter; left time: 124.9110s
# 	iters: 210, epoch: 3 | loss: 0.4763600
# 	speed: 0.0632s/iter; left time: 120.3023s
# 	iters: 240, epoch: 3 | loss: 0.4047615
# 	speed: 0.0643s/iter; left time: 120.4109s
# Epoch: 3 cost time: 17.175854206085205
# Epoch: 3, Steps: 264 | Train Loss: 0.4317974 Vali Loss: 0.8148521 Test Loss: 0.4633624
# Validation loss decreased (0.844605 --> 0.814852).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.4098701
# 	speed: 0.1725s/iter; left time: 313.7525s
# 	iters: 60, epoch: 4 | loss: 0.4554054
# 	speed: 0.0637s/iter; left time: 114.0086s
# 	iters: 90, epoch: 4 | loss: 0.4508789
# 	speed: 0.0642s/iter; left time: 112.9595s
# 	iters: 120, epoch: 4 | loss: 0.4179057
# 	speed: 0.0670s/iter; left time: 115.9188s
# 	iters: 150, epoch: 4 | loss: 0.4358285
# 	speed: 0.0636s/iter; left time: 108.0937s
# 	iters: 180, epoch: 4 | loss: 0.4461879
# 	speed: 0.0642s/iter; left time: 107.1383s
# 	iters: 210, epoch: 4 | loss: 0.4589182
# 	speed: 0.0639s/iter; left time: 104.7900s
# 	iters: 240, epoch: 4 | loss: 0.3661171
# 	speed: 0.0631s/iter; left time: 101.5701s
# Epoch: 4 cost time: 17.004894256591797
# Epoch: 4, Steps: 264 | Train Loss: 0.4234940 Vali Loss: 0.8016976 Test Loss: 0.4559059
# Validation loss decreased (0.814852 --> 0.801698).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.4116602
# 	speed: 0.1714s/iter; left time: 266.4577s
# 	iters: 60, epoch: 5 | loss: 0.3537520
# 	speed: 0.0637s/iter; left time: 97.1410s
# 	iters: 90, epoch: 5 | loss: 0.3878417
# 	speed: 0.0638s/iter; left time: 95.3211s
# 	iters: 120, epoch: 5 | loss: 0.4329871
# 	speed: 0.0638s/iter; left time: 93.4010s
# 	iters: 150, epoch: 5 | loss: 0.4801364
# 	speed: 0.0662s/iter; left time: 94.9497s
# 	iters: 180, epoch: 5 | loss: 0.4164673
# 	speed: 0.0638s/iter; left time: 89.6837s
# 	iters: 210, epoch: 5 | loss: 0.4280387
# 	speed: 0.0640s/iter; left time: 87.9610s
# 	iters: 240, epoch: 5 | loss: 0.4111709
# 	speed: 0.0638s/iter; left time: 85.8627s
# Epoch: 5 cost time: 17.017504453659058
# Epoch: 5, Steps: 264 | Train Loss: 0.4197029 Vali Loss: 0.7965782 Test Loss: 0.4523278
# Validation loss decreased (0.801698 --> 0.796578).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.4116252
# 	speed: 0.1738s/iter; left time: 224.4021s
# 	iters: 60, epoch: 6 | loss: 0.4509417
# 	speed: 0.0649s/iter; left time: 81.8756s
# 	iters: 90, epoch: 6 | loss: 0.3828391
# 	speed: 0.0649s/iter; left time: 79.9006s
# 	iters: 120, epoch: 6 | loss: 0.4007793
# 	speed: 0.0641s/iter; left time: 76.9771s
# 	iters: 150, epoch: 6 | loss: 0.3995775
# 	speed: 0.0657s/iter; left time: 76.9339s
# 	iters: 180, epoch: 6 | loss: 0.4005135
# 	speed: 0.0657s/iter; left time: 74.9848s
# 	iters: 210, epoch: 6 | loss: 0.3568096
# 	speed: 0.0646s/iter; left time: 71.7340s
# 	iters: 240, epoch: 6 | loss: 0.4092644
# 	speed: 0.0653s/iter; left time: 70.5381s
# Epoch: 6 cost time: 17.250876903533936
# Epoch: 6, Steps: 264 | Train Loss: 0.4180532 Vali Loss: 0.7935519 Test Loss: 0.4505485
# Validation loss decreased (0.796578 --> 0.793552).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.3676239
# 	speed: 0.1706s/iter; left time: 175.2412s
# 	iters: 60, epoch: 7 | loss: 0.4483372
# 	speed: 0.0632s/iter; left time: 62.9698s
# 	iters: 90, epoch: 7 | loss: 0.3978041
# 	speed: 0.0629s/iter; left time: 60.8517s
# 	iters: 120, epoch: 7 | loss: 0.4310921
# 	speed: 0.0635s/iter; left time: 59.5400s
# 	iters: 150, epoch: 7 | loss: 0.4092602
# 	speed: 0.0646s/iter; left time: 58.5903s
# 	iters: 180, epoch: 7 | loss: 0.3908742
# 	speed: 0.0648s/iter; left time: 56.8203s
# 	iters: 210, epoch: 7 | loss: 0.4067613
# 	speed: 0.0632s/iter; left time: 53.5501s
# 	iters: 240, epoch: 7 | loss: 0.4276841
# 	speed: 0.0636s/iter; left time: 51.9641s
# Epoch: 7 cost time: 16.94062352180481
# Epoch: 7, Steps: 264 | Train Loss: 0.4168325 Vali Loss: 0.7920586 Test Loss: 0.4496310
# Validation loss decreased (0.793552 --> 0.792059).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.4780906
# 	speed: 0.1678s/iter; left time: 128.0558s
# 	iters: 60, epoch: 8 | loss: 0.4162325
# 	speed: 0.0653s/iter; left time: 47.9006s
# 	iters: 90, epoch: 8 | loss: 0.3805212
# 	speed: 0.0642s/iter; left time: 45.1422s
# 	iters: 120, epoch: 8 | loss: 0.4242885
# 	speed: 0.0651s/iter; left time: 43.8173s
# 	iters: 150, epoch: 8 | loss: 0.4391073
# 	speed: 0.0647s/iter; left time: 41.5864s
# 	iters: 180, epoch: 8 | loss: 0.4036987
# 	speed: 0.0632s/iter; left time: 38.7389s
# 	iters: 210, epoch: 8 | loss: 0.4246282
# 	speed: 0.0649s/iter; left time: 37.8397s
# 	iters: 240, epoch: 8 | loss: 0.3947469
# 	speed: 0.0637s/iter; left time: 35.2428s
# Epoch: 8 cost time: 17.033414363861084
# Epoch: 8, Steps: 264 | Train Loss: 0.4164280 Vali Loss: 0.7913841 Test Loss: 0.4491766
# Validation loss decreased (0.792059 --> 0.791384).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.4107543
# 	speed: 0.1701s/iter; left time: 84.8878s
# 	iters: 60, epoch: 9 | loss: 0.4296199
# 	speed: 0.0646s/iter; left time: 30.3094s
# 	iters: 90, epoch: 9 | loss: 0.3473655
# 	speed: 0.0657s/iter; left time: 28.8527s
# 	iters: 120, epoch: 9 | loss: 0.4085090
# 	speed: 0.0639s/iter; left time: 26.1475s
# 	iters: 150, epoch: 9 | loss: 0.4151588
# 	speed: 0.0644s/iter; left time: 24.4164s
# 	iters: 180, epoch: 9 | loss: 0.4212051
# 	speed: 0.0644s/iter; left time: 22.4747s
# 	iters: 210, epoch: 9 | loss: 0.3835836
# 	speed: 0.0640s/iter; left time: 20.4229s
# 	iters: 240, epoch: 9 | loss: 0.3495104
# 	speed: 0.0659s/iter; left time: 19.0324s
# Epoch: 9 cost time: 17.138851165771484
# Epoch: 9, Steps: 264 | Train Loss: 0.4163742 Vali Loss: 0.7910093 Test Loss: 0.4489455
# Validation loss decreased (0.791384 --> 0.791009).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.4414547
# 	speed: 0.1731s/iter; left time: 40.6885s
# 	iters: 60, epoch: 10 | loss: 0.3942051
# 	speed: 0.0642s/iter; left time: 13.1691s
# 	iters: 90, epoch: 10 | loss: 0.3884856
# 	speed: 0.0661s/iter; left time: 11.5670s
# 	iters: 120, epoch: 10 | loss: 0.5167188
# 	speed: 0.0637s/iter; left time: 9.2373s
# 	iters: 150, epoch: 10 | loss: 0.3501650
# 	speed: 0.0620s/iter; left time: 7.1314s
# 	iters: 180, epoch: 10 | loss: 0.4111653
# 	speed: 0.0633s/iter; left time: 5.3838s
# 	iters: 210, epoch: 10 | loss: 0.3698113
# 	speed: 0.0639s/iter; left time: 3.5152s
# 	iters: 240, epoch: 10 | loss: 0.4797205
# 	speed: 0.0649s/iter; left time: 1.6229s
# Epoch: 10 cost time: 16.97560739517212
# Epoch: 10, Steps: 264 | Train Loss: 0.4160880 Vali Loss: 0.7902477 Test Loss: 0.4488293
# Validation loss decreased (0.791009 --> 0.790248).  Saving model ...
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : ETTh1_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 2785
# test shape: (87, 32, 96, 7) (87, 32, 96, 7)
# test shape: (2784, 96, 7) (2784, 96, 7)
# mse:0.4488292932510376, mae:0.444854199886322
# rmse:0.6699472069740295, mape:0.7250699400901794, mspe:41021.8125
# rse:0.6363475322723389, corr:25.530532836914062, smape:0.8207985162734985, wape:0.5588721036911011, r2:0.5950618386268616
#
# SUCCESS: Finished FFT_dual on ETTh1
#
#
# ====================================================================================================
# DATASET: ETTm1 | variates=7
# ====================================================================================================
#
# >>> Training SWT_original on ETTm1 <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='ETTm1_SimpleTM_SWT_original', model='SimpleTM_SWT', data='ETTm1', root_path='./dataset/SimpleTM_datasets/ETT-small', data_path='ETTm1.csv', features='M', target='OT', freq='t', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=7, dec_in=7, c_out=7, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db1', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=32, d_ff=32, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 12856
# Memory usage for trainable parameters: 0.05 MB
# Static memory footprint (allocated): 0.06 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : ETTm1_SimpleTM_SWT_original_ETTm1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 34369
# val 11425
# test 11425
# 	iters: 30, epoch: 1 | loss: 0.5203099
# 	speed: 0.0861s/iter; left time: 922.5547s
# 	iters: 60, epoch: 1 | loss: 0.5476154
# 	speed: 0.0703s/iter; left time: 750.8886s
# 	iters: 90, epoch: 1 | loss: 0.5745894
# 	speed: 0.0684s/iter; left time: 728.0261s
# 	iters: 120, epoch: 1 | loss: 0.5303614
# 	speed: 0.0681s/iter; left time: 722.7955s
# 	iters: 150, epoch: 1 | loss: 0.3869784
# 	speed: 0.0679s/iter; left time: 719.1305s
# 	iters: 180, epoch: 1 | loss: 0.4291982
# 	speed: 0.0682s/iter; left time: 720.0048s
# 	iters: 210, epoch: 1 | loss: 0.4443043
# 	speed: 0.0753s/iter; left time: 792.8388s
# 	iters: 240, epoch: 1 | loss: 0.4360264
# 	speed: 0.0678s/iter; left time: 712.2283s
# 	iters: 270, epoch: 1 | loss: 0.3975336
# 	speed: 0.0692s/iter; left time: 724.1409s
# 	iters: 300, epoch: 1 | loss: 0.4377582
# 	speed: 0.0681s/iter; left time: 710.8786s
# 	iters: 330, epoch: 1 | loss: 0.4358831
# 	speed: 0.0678s/iter; left time: 705.7900s
# 	iters: 360, epoch: 1 | loss: 0.4433421
# 	speed: 0.0685s/iter; left time: 711.4860s
# 	iters: 390, epoch: 1 | loss: 0.3981633
# 	speed: 0.0678s/iter; left time: 701.7594s
# 	iters: 420, epoch: 1 | loss: 0.4040100
# 	speed: 0.0696s/iter; left time: 718.2004s
# 	iters: 450, epoch: 1 | loss: 0.3854783
# 	speed: 0.0687s/iter; left time: 707.1511s
# 	iters: 480, epoch: 1 | loss: 0.4289710
# 	speed: 0.0680s/iter; left time: 697.8775s
# 	iters: 510, epoch: 1 | loss: 0.3593466
# 	speed: 0.0686s/iter; left time: 702.0423s
# 	iters: 540, epoch: 1 | loss: 0.3851348
# 	speed: 0.0680s/iter; left time: 693.7782s
# 	iters: 570, epoch: 1 | loss: 0.3593329
# 	speed: 0.0686s/iter; left time: 697.2732s
# 	iters: 600, epoch: 1 | loss: 0.4257489
# 	speed: 0.0681s/iter; left time: 690.2950s
# 	iters: 630, epoch: 1 | loss: 0.3294332
# 	speed: 0.0672s/iter; left time: 679.9348s
# 	iters: 660, epoch: 1 | loss: 0.4130807
# 	speed: 0.0687s/iter; left time: 692.1094s
# 	iters: 690, epoch: 1 | loss: 0.4053378
# 	speed: 0.0693s/iter; left time: 696.8519s
# 	iters: 720, epoch: 1 | loss: 0.5187814
# 	speed: 0.0694s/iter; left time: 695.9368s
# 	iters: 750, epoch: 1 | loss: 0.4197788
# 	speed: 0.0685s/iter; left time: 684.2714s
# 	iters: 780, epoch: 1 | loss: 0.3778424
# 	speed: 0.0680s/iter; left time: 677.7190s
# 	iters: 810, epoch: 1 | loss: 0.4311097
# ...
# test 1319
# test shape: (41, 32, 96, 37) (41, 32, 96, 37)
# test shape: (1312, 96, 37) (1312, 96, 37)
# mse:0.5622133016586304, mae:0.49791979789733887
# rmse:0.7498088479042053, mape:0.6989277005195618, mspe:995.6260986328125
# rse:0.6575564742088318, corr:17.51072883605957, smape:0.8555911779403687, wape:0.6254344582557678, r2:0.5676194429397583
#
# SUCCESS: Finished SWT_dual on smartbuilding
#
# >>> Training FFT_original on smartbuilding <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='smartbuilding_SimpleTM_FFT_original', model='SimpleTM_FFT', data='custom', root_path='./dataset/SimpleTM_datasets/smartbuilding', data_path='smart.csv', features='M', target='Floor_Total(kW)', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=37, dec_in=37, c_out=37, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db4', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=64, d_ff=128, e_layers=1, compile=False, output_attention=False, attention_mode='original', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 46056
# Memory usage for trainable parameters: 0.18 MB
# Static memory footprint (allocated): 0.18 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : smartbuilding_SimpleTM_FFT_original_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 4758
# val 612
# test 1319
# 	iters: 30, epoch: 1 | loss: 1.0875701
# 	speed: 0.0750s/iter; left time: 108.8760s
# 	iters: 60, epoch: 1 | loss: 1.0201105
# 	speed: 0.0521s/iter; left time: 74.1013s
# 	iters: 90, epoch: 1 | loss: 0.8486070
# 	speed: 0.0512s/iter; left time: 71.2375s
# 	iters: 120, epoch: 1 | loss: 0.7908233
# 	speed: 0.0515s/iter; left time: 70.0426s
# Epoch: 1 cost time: 8.366557836532593
# Epoch: 1, Steps: 148 | Train Loss: 0.9739521 Vali Loss: 0.6996938 Test Loss: 0.6882580
# Validation loss decreased (inf --> 0.699694).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.6863574
# 	speed: 0.1306s/iter; left time: 170.1570s
# 	iters: 60, epoch: 2 | loss: 0.7293648
# 	speed: 0.0525s/iter; left time: 66.7770s
# 	iters: 90, epoch: 2 | loss: 0.6871842
# 	speed: 0.0536s/iter; left time: 66.6658s
# 	iters: 120, epoch: 2 | loss: 0.6955944
# 	speed: 0.0520s/iter; left time: 63.1330s
# Epoch: 2 cost time: 7.920638084411621
# Epoch: 2, Steps: 148 | Train Loss: 0.7469120 Vali Loss: 0.6071169 Test Loss: 0.6004324
# Validation loss decreased (0.699694 --> 0.607117).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.8338209
# 	speed: 0.1309s/iter; left time: 151.1398s
# 	iters: 60, epoch: 3 | loss: 0.6997406
# 	speed: 0.0520s/iter; left time: 58.5206s
# 	iters: 90, epoch: 3 | loss: 0.6839081
# 	speed: 0.0527s/iter; left time: 57.7258s
# 	iters: 120, epoch: 3 | loss: 0.6836979
# 	speed: 0.0534s/iter; left time: 56.9054s
# Epoch: 3 cost time: 7.882728815078735
# Epoch: 3, Steps: 148 | Train Loss: 0.7050201 Vali Loss: 0.5884817 Test Loss: 0.5834731
# Validation loss decreased (0.607117 --> 0.588482).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.6237938
# 	speed: 0.1322s/iter; left time: 133.1564s
# 	iters: 60, epoch: 4 | loss: 0.7583047
# 	speed: 0.0512s/iter; left time: 50.0083s
# 	iters: 90, epoch: 4 | loss: 0.6656268
# 	speed: 0.0519s/iter; left time: 49.1444s
# 	iters: 120, epoch: 4 | loss: 0.6216279
# 	speed: 0.0517s/iter; left time: 47.3717s
# Epoch: 4 cost time: 7.77879524230957
# Epoch: 4, Steps: 148 | Train Loss: 0.6928878 Vali Loss: 0.5789343 Test Loss: 0.5765605
# Validation loss decreased (0.588482 --> 0.578934).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.7991220
# 	speed: 0.1314s/iter; left time: 112.8877s
# 	iters: 60, epoch: 5 | loss: 0.6619061
# 	speed: 0.0510s/iter; left time: 42.3079s
# 	iters: 90, epoch: 5 | loss: 0.7638351
# 	speed: 0.0512s/iter; left time: 40.8939s
# 	iters: 120, epoch: 5 | loss: 0.7394454
# 	speed: 0.0513s/iter; left time: 39.4556s
# Epoch: 5 cost time: 7.78037428855896
# Epoch: 5, Steps: 148 | Train Loss: 0.6880664 Vali Loss: 0.5759993 Test Loss: 0.5732273
# Validation loss decreased (0.578934 --> 0.575999).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.6008226
# 	speed: 0.1333s/iter; left time: 94.7658s
# 	iters: 60, epoch: 6 | loss: 0.7082229
# 	speed: 0.0512s/iter; left time: 34.8622s
# 	iters: 90, epoch: 6 | loss: 0.6771781
# 	speed: 0.0518s/iter; left time: 33.6986s
# 	iters: 120, epoch: 6 | loss: 0.8087639
# 	speed: 0.0522s/iter; left time: 32.4020s
# Epoch: 6 cost time: 7.788150787353516
# Epoch: 6, Steps: 148 | Train Loss: 0.6847417 Vali Loss: 0.5742694 Test Loss: 0.5715602
# Validation loss decreased (0.575999 --> 0.574269).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.7900227
# 	speed: 0.1323s/iter; left time: 74.4573s
# 	iters: 60, epoch: 7 | loss: 0.7801380
# 	speed: 0.0521s/iter; left time: 27.7925s
# 	iters: 90, epoch: 7 | loss: 0.6281930
# 	speed: 0.0514s/iter; left time: 25.8341s
# 	iters: 120, epoch: 7 | loss: 0.5935314
# 	speed: 0.0518s/iter; left time: 24.5074s
# Epoch: 7 cost time: 7.785507440567017
# Epoch: 7, Steps: 148 | Train Loss: 0.6839692 Vali Loss: 0.5732208 Test Loss: 0.5707269
# Validation loss decreased (0.574269 --> 0.573221).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.6323909
# 	speed: 0.1319s/iter; left time: 54.7494s
# 	iters: 60, epoch: 8 | loss: 0.6325819
# 	speed: 0.0527s/iter; left time: 20.2938s
# 	iters: 90, epoch: 8 | loss: 0.6805305
# 	speed: 0.0515s/iter; left time: 18.2942s
# 	iters: 120, epoch: 8 | loss: 0.6547990
# 	speed: 0.0521s/iter; left time: 16.9442s
# Epoch: 8 cost time: 7.837967157363892
# Epoch: 8, Steps: 148 | Train Loss: 0.6835026 Vali Loss: 0.5723274 Test Loss: 0.5702869
# Validation loss decreased (0.573221 --> 0.572327).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.6949100
# 	speed: 0.1409s/iter; left time: 37.6316s
# 	iters: 60, epoch: 9 | loss: 0.7705752
# 	speed: 0.0527s/iter; left time: 12.4803s
# 	iters: 90, epoch: 9 | loss: 0.6444448
# 	speed: 0.0524s/iter; left time: 10.8545s
# 	iters: 120, epoch: 9 | loss: 0.6782292
# 	speed: 0.0520s/iter; left time: 9.2074s
# Epoch: 9 cost time: 8.104998350143433
# Epoch: 9, Steps: 148 | Train Loss: 0.6827998 Vali Loss: 0.5722670 Test Loss: 0.5700732
# Validation loss decreased (0.572327 --> 0.572267).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.6065846
# 	speed: 0.1299s/iter; left time: 15.4576s
# 	iters: 60, epoch: 10 | loss: 0.6344296
# 	speed: 0.0509s/iter; left time: 4.5306s
# 	iters: 90, epoch: 10 | loss: 0.6055331
# 	speed: 0.0529s/iter; left time: 3.1220s
# 	iters: 120, epoch: 10 | loss: 0.7948409
# 	speed: 0.0522s/iter; left time: 1.5141s
# Epoch: 10 cost time: 7.7708868980407715
# Epoch: 10, Steps: 148 | Train Loss: 0.6827042 Vali Loss: 0.5727005 Test Loss: 0.5699611
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : smartbuilding_SimpleTM_FFT_original_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 1319
# test shape: (41, 32, 96, 37) (41, 32, 96, 37)
# test shape: (1312, 96, 37) (1312, 96, 37)
# mse:0.5700733661651611, mae:0.5030419230461121
# rmse:0.7550320029258728, mape:0.7016569972038269, mspe:939.7139892578125
# rse:0.6621370315551758, corr:17.252363204956055, smape:0.8611859679222107, wape:0.631868302822113, r2:0.5615745782852173
#
# SUCCESS: Finished FFT_original on smartbuilding
#
# >>> Training FFT_dual on smartbuilding <<<
#
# Args in experiment:
# Namespace(is_training=1, model_id='smartbuilding_SimpleTM_FFT_dual', model='SimpleTM_FFT', data='custom', root_path='./dataset/SimpleTM_datasets/smartbuilding', data_path='smart.csv', features='M', target='Floor_Total(kW)', freq='h', checkpoints='/kaggle/working/SimpleTM_AllDatasets_Smart_Results/checkpoints/', seq_len=96, label_len=0, pred_len=96, enc_in=37, dec_in=37, c_out=37, n_heads=8, d_layers=1, moving_avg=25, factor=1, distil=True, dropout=0.1, geomattn_dropout=0.5, embed='timeF', activation='gelu', do_predict=False, num_workers=2, itr=1, train_epochs=10, batch_size=32, patience=3, learning_rate=0.0001, des='test', loss='MSE', lradj='type1', pct_start=0.2, use_amp=False, use_gpu=True, gpu=0, use_multi_gpu=False, devices='0,1,2,3', exp_name='MTSF', channel_independence=False, inverse=False, class_strategy='projection', target_root_path='./data/electricity/', target_data_path='electricity.csv', efficient_training=False, use_norm=1, partial_start_index=0, requires_grad=True, wv='db4', m=3, kernel_size=None, alpha=1.0, l1_weight=5e-05, d_model=64, d_ff=128, e_layers=1, compile=False, output_attention=False, attention_mode='dual', fix_seed=2025)
# Use GPU: cuda:0
# Total trainable parameters: 60001
# Memory usage for trainable parameters: 0.23 MB
# Static memory footprint (allocated): 0.24 MB
# Static memory footprint (reserved): 2.00 MB
# >>>>>>>start training : smartbuilding_SimpleTM_FFT_dual_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 4758
# val 612
# test 1319
# 	iters: 30, epoch: 1 | loss: 1.0815113
# 	speed: 0.0902s/iter; left time: 130.8759s
# 	iters: 60, epoch: 1 | loss: 0.9349348
# 	speed: 0.0671s/iter; left time: 95.3575s
# 	iters: 90, epoch: 1 | loss: 0.8445203
# 	speed: 0.0670s/iter; left time: 93.2643s
# 	iters: 120, epoch: 1 | loss: 0.8466897
# 	speed: 0.0681s/iter; left time: 92.7299s
# Epoch: 1 cost time: 10.734807968139648
# Epoch: 1, Steps: 148 | Train Loss: 0.9398376 Vali Loss: 0.6856259 Test Loss: 0.6709318
# Validation loss decreased (inf --> 0.685626).  Saving model ...
# Updating learning rate to 0.0001
# 	iters: 30, epoch: 2 | loss: 0.7279158
# 	speed: 0.1648s/iter; left time: 214.7363s
# 	iters: 60, epoch: 2 | loss: 0.6834379
# 	speed: 0.0677s/iter; left time: 86.1959s
# 	iters: 90, epoch: 2 | loss: 0.6984699
# 	speed: 0.0673s/iter; left time: 83.6067s
# 	iters: 120, epoch: 2 | loss: 0.6818522
# 	speed: 0.0684s/iter; left time: 82.9473s
# Epoch: 2 cost time: 10.087054252624512
# Epoch: 2, Steps: 148 | Train Loss: 0.7383989 Vali Loss: 0.6051545 Test Loss: 0.5958368
# Validation loss decreased (0.685626 --> 0.605154).  Saving model ...
# Updating learning rate to 5e-05
# 	iters: 30, epoch: 3 | loss: 0.8019786
# 	speed: 0.1679s/iter; left time: 193.9283s
# 	iters: 60, epoch: 3 | loss: 0.7257980
# 	speed: 0.0675s/iter; left time: 75.9285s
# 	iters: 90, epoch: 3 | loss: 0.7308806
# 	speed: 0.0687s/iter; left time: 75.1797s
# 	iters: 120, epoch: 3 | loss: 0.7339995
# 	speed: 0.0668s/iter; left time: 71.1199s
# Epoch: 3 cost time: 10.314394235610962
# Epoch: 3, Steps: 148 | Train Loss: 0.7011192 Vali Loss: 0.5848038 Test Loss: 0.5786344
# Validation loss decreased (0.605154 --> 0.584804).  Saving model ...
# Updating learning rate to 2.5e-05
# 	iters: 30, epoch: 4 | loss: 0.7387194
# 	speed: 0.1618s/iter; left time: 162.9450s
# 	iters: 60, epoch: 4 | loss: 0.6455395
# 	speed: 0.0678s/iter; left time: 66.2109s
# 	iters: 90, epoch: 4 | loss: 0.7142269
# 	speed: 0.0693s/iter; left time: 65.6228s
# 	iters: 120, epoch: 4 | loss: 0.6006735
# 	speed: 0.0688s/iter; left time: 63.0937s
# Epoch: 4 cost time: 10.292203903198242
# Epoch: 4, Steps: 148 | Train Loss: 0.6889861 Vali Loss: 0.5750229 Test Loss: 0.5707829
# Validation loss decreased (0.584804 --> 0.575023).  Saving model ...
# Updating learning rate to 1.25e-05
# 	iters: 30, epoch: 5 | loss: 0.6833601
# 	speed: 0.1625s/iter; left time: 139.5604s
# 	iters: 60, epoch: 5 | loss: 0.7676293
# 	speed: 0.0684s/iter; left time: 56.6748s
# 	iters: 90, epoch: 5 | loss: 0.8382725
# 	speed: 0.0682s/iter; left time: 54.4938s
# 	iters: 120, epoch: 5 | loss: 0.6845668
# 	speed: 0.0676s/iter; left time: 51.9533s
# Epoch: 5 cost time: 10.145209312438965
# Epoch: 5, Steps: 148 | Train Loss: 0.6832325 Vali Loss: 0.5704293 Test Loss: 0.5668992
# Validation loss decreased (0.575023 --> 0.570429).  Saving model ...
# Updating learning rate to 6.25e-06
# 	iters: 30, epoch: 6 | loss: 0.7593792
# 	speed: 0.1610s/iter; left time: 114.4748s
# 	iters: 60, epoch: 6 | loss: 0.6557332
# 	speed: 0.0690s/iter; left time: 47.0223s
# 	iters: 90, epoch: 6 | loss: 0.6231151
# 	speed: 0.0680s/iter; left time: 44.2972s
# 	iters: 120, epoch: 6 | loss: 0.6063399
# 	speed: 0.0682s/iter; left time: 42.3462s
# Epoch: 6 cost time: 10.171252250671387
# Epoch: 6, Steps: 148 | Train Loss: 0.6810635 Vali Loss: 0.5689899 Test Loss: 0.5649475
# Validation loss decreased (0.570429 --> 0.568990).  Saving model ...
# Updating learning rate to 3.125e-06
# 	iters: 30, epoch: 7 | loss: 0.6770299
# 	speed: 0.1660s/iter; left time: 93.4658s
# 	iters: 60, epoch: 7 | loss: 0.6746996
# 	speed: 0.0687s/iter; left time: 36.6041s
# 	iters: 90, epoch: 7 | loss: 0.7000578
# 	speed: 0.0674s/iter; left time: 33.8809s
# 	iters: 120, epoch: 7 | loss: 0.7770145
# 	speed: 0.0681s/iter; left time: 32.2208s
# Epoch: 7 cost time: 10.291048288345337
# Epoch: 7, Steps: 148 | Train Loss: 0.6791937 Vali Loss: 0.5666930 Test Loss: 0.5639693
# Validation loss decreased (0.568990 --> 0.566693).  Saving model ...
# Updating learning rate to 1.5625e-06
# 	iters: 30, epoch: 8 | loss: 0.7916293
# 	speed: 0.1633s/iter; left time: 67.7855s
# 	iters: 60, epoch: 8 | loss: 0.6482033
# 	speed: 0.0675s/iter; left time: 25.9909s
# 	iters: 90, epoch: 8 | loss: 0.6613555
# 	speed: 0.0671s/iter; left time: 23.8303s
# 	iters: 120, epoch: 8 | loss: 0.7377808
# 	speed: 0.0669s/iter; left time: 21.7573s
# Epoch: 8 cost time: 10.165616512298584
# Epoch: 8, Steps: 148 | Train Loss: 0.6786195 Vali Loss: 0.5663908 Test Loss: 0.5634792
# Validation loss decreased (0.566693 --> 0.566391).  Saving model ...
# Updating learning rate to 7.8125e-07
# 	iters: 30, epoch: 9 | loss: 0.7261565
# 	speed: 0.1652s/iter; left time: 44.0981s
# 	iters: 60, epoch: 9 | loss: 0.6855063
# 	speed: 0.0681s/iter; left time: 16.1498s
# 	iters: 90, epoch: 9 | loss: 0.6801155
# 	speed: 0.0672s/iter; left time: 13.9036s
# 	iters: 120, epoch: 9 | loss: 0.6860616
# 	speed: 0.0665s/iter; left time: 11.7692s
# Epoch: 9 cost time: 10.120163202285767
# Epoch: 9, Steps: 148 | Train Loss: 0.6788360 Vali Loss: 0.5645514 Test Loss: 0.5632257
# Validation loss decreased (0.566391 --> 0.564551).  Saving model ...
# Updating learning rate to 3.90625e-07
# 	iters: 30, epoch: 10 | loss: 0.6917981
# 	speed: 0.1627s/iter; left time: 19.3644s
# 	iters: 60, epoch: 10 | loss: 0.7189646
# 	speed: 0.0689s/iter; left time: 6.1335s
# 	iters: 90, epoch: 10 | loss: 0.7061744
# 	speed: 0.0680s/iter; left time: 4.0110s
# 	iters: 120, epoch: 10 | loss: 0.7943434
# 	speed: 0.0678s/iter; left time: 1.9649s
# Epoch: 10 cost time: 10.212496995925903
# Epoch: 10, Steps: 148 | Train Loss: 0.6770291 Vali Loss: 0.5659947 Test Loss: 0.5630980
# EarlyStopping counter: 1 out of 3
# Updating learning rate to 1.953125e-07
# >>>>>>>testing : smartbuilding_SimpleTM_FFT_dual_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 1319
# test shape: (41, 32, 96, 37) (41, 32, 96, 37)
# test shape: (1312, 96, 37) (1312, 96, 37)
# mse:0.5632255673408508, mae:0.4987516701221466
# rmse:0.7504835724830627, mape:0.6986121535301208, mspe:987.5512084960938
# rse:0.6581481695175171, corr:17.469568252563477, smape:0.8566510677337646, wape:0.6264793872833252, r2:0.5668410062789917
#
# SUCCESS: Finished FFT_dual on smartbuilding
#
#
# Gathering generated PDF plots...
# Copied PDF plots to /kaggle/working/SimpleTM_AllDatasets_Smart_Results/plots/
# Copied metric text results to output directory.

# %%
import re

results_file = os.path.join(OUTPUT_DIR, 'result_long_term_forecast.txt')
metric_order = ['MSE', 'MAE', 'RMSE', 'MAPE', 'MSPE', 'RSE', 'CORR', 'SMAPE', 'WAPE', 'R2']
pattern = re.compile(r'^(?P<dataset>[^_]+)_(?P<model>SimpleTM_(?:SWT|FFT))_(?P<attention>original|dual)_')
metric_pattern = re.compile(r'([a-zA-Z0-9_]+):([^,]+)')

if os.path.exists(results_file):
    with open(results_file, 'r', encoding='utf-8') as f:
        content = f.read().strip()

    entries = content.split('\n\n') if content else []
    rows = []
    for entry in entries:
        lines = [line.strip() for line in entry.splitlines() if line.strip()]
        if len(lines) < 2:
            continue
        setting = lines[0]
        metrics_line = lines[-1]
        match = pattern.search(setting)
        if not match:
            continue

        model_type = match.group('model')
        attention_mode = match.group('attention')
        tokenization = 'SWT' if model_type.endswith('SWT') else 'FFT'
        row = {
            'Dataset': match.group('dataset'),
            'Model': model_type,
            'AttentionMode': attention_mode,
            'Variant': f'{tokenization}_{attention_mode}',
            'Setting': setting,
        }
        for metric_name, value in metric_pattern.findall(metrics_line):
            try:
                row[metric_name.upper()] = float(value.strip())
            except ValueError:
                pass
        rows.append(row)

    if rows:
        df = pd.DataFrame(rows).sort_values(['Dataset', 'Model', 'AttentionMode']).reset_index(drop=True)
        print(df.to_string(index=False))

        raw_path = os.path.join(OUTPUT_DIR, 'raw_metrics.csv')
        df.to_csv(raw_path, index=False)

        value_columns = [col for col in metric_order if col in df.columns]
        pivot_df = df.pivot(index='Dataset', columns='Variant', values=value_columns)
        variant_order = ['SWT_original', 'SWT_dual', 'FFT_original', 'FFT_dual']
        pivot_df = pivot_df.reindex(columns=variant_order, level=1)
        final_path = os.path.join(OUTPUT_DIR, 'final_metrics.csv')
        pivot_df.to_csv(final_path)

        print(f'\nSaved raw results to: {raw_path}')
        print(f'Saved final table to: {final_path}')
    else:
        print('No valid metrics found in result file.')
else:
    print('Result file not found.')
# Out:
#       Dataset        Model AttentionMode      Variant                                                                                               Setting       MAE         MSE      RMSE     MAPE         MSPE      RSE      CORR    SMAPE     WAPE       R2
#         ETTh1 SimpleTM_FFT          dual     FFT_dual               ETTh1_SimpleTM_FFT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.444854    0.448829  0.669947 0.725070 4.102181e+04 0.636348 25.530533 0.820799 0.558872 0.595062
#         ETTh1 SimpleTM_FFT      original FFT_original           ETTh1_SimpleTM_FFT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.449469    0.457091  0.676085 0.731739 4.093601e+04 0.642178 25.518358 0.826550 0.564669 0.587608
#         ETTh1 SimpleTM_SWT          dual     SWT_dual               ETTh1_SimpleTM_SWT_dual_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.443600    0.446452  0.668171 0.723741 4.153827e+04 0.634660 25.527323 0.818541 0.557297 0.597206
#         ETTh1 SimpleTM_SWT      original SWT_original           ETTh1_SimpleTM_SWT_original_ETTh1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.446162    0.451259  0.671758 0.728277 4.273498e+04 0.638067 25.480476 0.819638 0.560516 0.592870
#         ETTm1 SimpleTM_FFT          dual     FFT_dual               ETTm1_SimpleTM_FFT_dual_ETTm1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.385665    0.357032  0.597522 0.676117 3.998266e+02 0.568568 51.141865 0.740470 0.487405 0.676731
#         ETTm1 SimpleTM_FFT      original FFT_original           ETTm1_SimpleTM_FFT_original_ETTm1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.382873    0.363031  0.602520 0.658607 3.508831e+02 0.573324 50.597622 0.740879 0.483877 0.671299
#         ETTm1 SimpleTM_SWT          dual     SWT_dual               ETTm1_SimpleTM_SWT_dual_ETTm1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.384758    0.358250  0.598540 0.666430 3.736508e+02 0.569537 50.798206 0.746773 0.486258 0.675628
#         ETTm1 SimpleTM_SWT      original SWT_original           ETTm1_SimpleTM_SWT_original_ETTm1_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.379085    0.349717  0.591369 0.665191 3.761813e+02 0.562713 50.939266 0.733216 0.479089 0.683354
#        PEMS03 SimpleTM_FFT          dual     FFT_dual           PEMS03_SimpleTM_FFT_dual_PEMS_96_96_256_1024_1_bior3.1_None_3_0.1_5e-05_0.002_TST_16_2025_0 26.435995 1859.610840 43.123207 0.279236 6.013112e+12 0.304840 14.884839 0.281202 0.152521 0.907073
#        PEMS03 SimpleTM_FFT      original FFT_original       PEMS03_SimpleTM_FFT_original_PEMS_96_96_256_1024_1_bior3.1_None_3_0.1_5e-05_0.002_TST_16_2025_0 24.088211 1525.211182 39.053951 0.246194 4.319464e+12 0.276074 15.098865 0.265143 0.138976 0.923783
#        PEMS03 SimpleTM_SWT          dual     SWT_dual           PEMS03_SimpleTM_SWT_dual_PEMS_96_96_256_1024_1_bior3.1_None_3_0.1_5e-05_0.002_TST_16_2025_0 20.835686 1151.840210 33.938770 0.225583 3.459109e+12 0.239915 14.936615 0.247864 0.120211 0.942441
#        PEMS03 SimpleTM_SWT      original SWT_original       PEMS03_SimpleTM_SWT_original_PEMS_96_96_256_1024_1_bior3.1_None_3_0.1_5e-05_0.002_TST_16_2025_0 20.778837 1153.876221 33.968754 0.222184 3.204133e+12 0.240127 14.960922 0.243779 0.119883 0.942339
#         Solar SimpleTM_FFT          dual     FFT_dual               Solar_SimpleTM_FFT_dual_Solar_96_96_128_256_1_db8_None_3_0.0_5e-05_0.003_TST_128_2025_0  0.301813    0.228688  0.478213 0.433020 5.391247e+04 0.555327 56.579163 0.503424 0.385060 0.691612
#         Solar SimpleTM_FFT      original FFT_original           Solar_SimpleTM_FFT_original_Solar_96_96_128_256_1_db8_None_3_0.0_5e-05_0.003_TST_128_2025_0  0.244125    0.189240  0.435017 0.357562 3.452029e+04 0.505165 56.198284 0.408670 0.311461 0.744808
#         Solar SimpleTM_SWT          dual     SWT_dual               Solar_SimpleTM_SWT_dual_Solar_96_96_128_256_1_db8_None_3_0.0_5e-05_0.003_TST_128_2025_0  0.243513    0.177451  0.421249 0.355742 3.811284e+04 0.489177 56.348679 0.405050 0.310680 0.760706
#         Solar SimpleTM_SWT      original SWT_original           Solar_SimpleTM_SWT_original_Solar_96_96_128_256_1_db8_None_3_0.0_5e-05_0.003_TST_128_2025_0  0.232734    0.171028  0.413556 0.346295 3.044912e+04 0.480243 55.297714 0.396241 0.296928 0.769367
#   electricity SimpleTM_FFT          dual     FFT_dual      electricity_SimpleTM_FFT_dual_custom_96_96_128_128_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.287395    0.193739  0.440158 0.511903 6.167998e+05 0.437585 45.623112 0.551410 0.346371 0.808520
#   electricity SimpleTM_FFT      original FFT_original  electricity_SimpleTM_FFT_original_custom_96_96_128_128_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.287456    0.203324  0.450915 0.505773 6.464580e+05 0.448279 45.223141 0.550544 0.346444 0.799046
#   electricity SimpleTM_SWT          dual     SWT_dual      electricity_SimpleTM_SWT_dual_custom_96_96_128_128_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.287238    0.193515  0.439903 0.512665 6.972166e+05 0.437331 45.660267 0.550353 0.346181 0.808742
#   electricity SimpleTM_SWT      original SWT_original  electricity_SimpleTM_SWT_original_custom_96_96_128_128_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.285882    0.202112  0.449569 0.505098 6.444641e+05 0.446941 45.308552 0.545436 0.344547 0.800244
# smartbuilding SimpleTM_FFT          dual     FFT_dual     smartbuilding_SimpleTM_FFT_dual_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.498752    0.563226  0.750484 0.698612 9.875512e+02 0.658148 17.469568 0.856651 0.626479 0.566841
# smartbuilding SimpleTM_FFT      original FFT_original smartbuilding_SimpleTM_FFT_original_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.503042    0.570073  0.755032 0.701657 9.397140e+02 0.662137 17.252363 0.861186 0.631868 0.561575
# smartbuilding SimpleTM_SWT          dual     SWT_dual     smartbuilding_SimpleTM_SWT_dual_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.497920    0.562213  0.749809 0.698928 9.956261e+02 0.657556 17.510729 0.855591 0.625434 0.567619
# smartbuilding SimpleTM_SWT      original SWT_original smartbuilding_SimpleTM_SWT_original_custom_96_96_64_128_1_db4_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.501880    0.569129  0.754406 0.702587 9.379105e+02 0.661588 17.356676 0.859159 0.630408 0.562301
#       traffic SimpleTM_FFT          dual     FFT_dual           traffic_SimpleTM_FFT_dual_custom_96_96_256_256_1_db1_None_3_1.0_5e-05_0.0001_type1_8_2025_1  0.363428    0.561252  0.749167 0.586705 6.978791e+05 0.620147 29.185547 0.636735 0.454621 0.615418
#       traffic SimpleTM_FFT      original FFT_original       traffic_SimpleTM_FFT_original_custom_96_96_256_256_1_db1_None_3_1.0_5e-05_0.0001_type1_8_2025_1  0.376752    0.601921  0.775836 0.580575 1.141380e+06 0.642222 29.987864 0.650450 0.471289 0.587551
#       traffic SimpleTM_SWT          dual     SWT_dual           traffic_SimpleTM_SWT_dual_custom_96_96_256_256_1_db1_None_3_1.0_5e-05_0.0001_type1_8_2025_1  0.354668    0.533398  0.730341 0.578273 9.368258e+05 0.604563 29.323296 0.614753 0.443663 0.634504
#       traffic SimpleTM_SWT      original SWT_original       traffic_SimpleTM_SWT_original_custom_96_96_256_256_1_db1_None_3_1.0_5e-05_0.0001_type1_8_2025_1  0.362473    0.577739  0.760092 0.564974 1.731265e+06 0.629190 29.748316 0.610393 0.453426 0.604120
#       weather SimpleTM_FFT          dual     FFT_dual            weather_SimpleTM_FFT_dual_custom_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.234042    0.191616  0.437740 0.522878 2.131114e+07 0.576796 43.090961 0.574942 0.385493 0.667306
#       weather SimpleTM_FFT      original FFT_original        weather_SimpleTM_FFT_original_custom_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.238129    0.197691  0.444624 0.527236 2.491188e+07 0.585867 42.819752 0.579561 0.392225 0.656760
#       weather SimpleTM_SWT          dual     SWT_dual            weather_SimpleTM_SWT_dual_custom_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.232468    0.192427  0.438665 0.522037 2.354627e+07 0.578015 43.047497 0.571135 0.382899 0.665899
#       weather SimpleTM_SWT      original SWT_original        weather_SimpleTM_SWT_original_custom_96_96_32_32_1_db1_None_3_1.0_5e-05_0.0001_type1_32_2025_1  0.233921    0.192925  0.439232 0.524168 2.499171e+07 0.578762 42.925976 0.573947 0.385294 0.665034
#
# Saved raw results to: /kaggle/working/SimpleTM_AllDatasets_Smart_Results/raw_metrics.csv
# Saved final table to: /kaggle/working/SimpleTM_AllDatasets_Smart_Results/final_metrics.csv

# %%
print("Packing logs, weights, plots, and results...")
archive_path = shutil.make_archive('/kaggle/working/SimpleTM_AllDatasets_Smart_Results', 'zip', OUTPUT_DIR)
print(f"\nDONE! Download {archive_path} from the Kaggle Output pane.")
# Out:
# Packing logs, weights, plots, and results...
#
# DONE! Download /kaggle/working/SimpleTM_AllDatasets_Smart_Results.zip from the Kaggle Output pane.
